# %% [markdown]
# #한글 폰트설치

# %%
# 필수 라이브러리 설치
# !pip install konlpy wordcloud matplotlib

# 한글 폰트 설정 (NanumGothic)
# !apt-get update -qq
# !apt-get install fonts-nanum -qq

# 폰트 설정
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from wordcloud import WordCloud

# 폰트 설정 함수
def set_korean_font():
    # 폰트 경로
    font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
    # fm._rebuild()  <- Remove or comment out this line.
    # Use the following to clear the font cache
    fm.fontManager.addfont(font_path)
    fm._load_fontmanager(try_read_cache=False) # This forces a rebuild without the internal method

    plt.rc('font', family='NanumGothic')
    plt.rcParams['axes.unicode_minus'] = False  # 마이너스 깨짐 방지
    print("한글 폰트 설정 완료:", font_path)
    return font_path

# 한글 폰트 설정 실행
font_path = set_korean_font()

# 기타 라이브러리 Import
import re
from konlpy.tag import Komoran
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.3.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 77.1 MB/s eta 0:00:00
# Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 42.0 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.2 konlpy-0.6.0
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# 한글 폰트 설정 완료: /usr/share/fonts/truetype/nanum/NanumGothic.ttf

# %%
# 테스트용 그래프
plt.figure(figsize=(5, 3))
plt.title("한글 폰트 테스트")
plt.plot([0, 1, 2], [0, 1, 4], label="테스트 라인")
plt.legend()
plt.show()

# %% [markdown]
# #데이터전처리

# %%
# 파일 경로 및 데이터 로드
file_paths = {
    "2015년 데이터": '/content/2015 중학교 기가 교과서 5종 생활자원 전체.txt',
    "2022년 데이터": '/content/20022 중학교 기가 교과서 5종 생활 자원 전체.txt',
}

category_files = [
    '/content/1. 빈곤퇴치.txt',
    '/content/2. 기아종식.txt',
    '/content/3. 건강과 웰빙중심.txt',
    '/content/4. 양질의 교육 보장.txt',
    '/content/5. 성평등 달성.txt',
    '/content/6. 깨끗한 물과 위생 보장.txt',
    '/content/7. 모두를 위한 에너지 보장.txt',
    '/content/8. 경제성장과 양질의 일자리.txt',
    '/content/9. 사회기반 시설 산업화 및 혁신.txt',
    '/content/10. 불평등 감소.txt',
    '/content/11. 지속가능한 도시와 주거지.txt',
    '/content/12. 지속가능한 소비와 생산.txt',
    '/content/13. 기후변화 대응.txt',
    '/content/14. 해양생태계 보존.txt',
    '/content/15. 육상생태계 보호.txt',
    '/content/16. 평화, 정의, 포용적인 제도.txt',
    '/content/17. 글로벌 파트너십.txt',
]

# 데이터 로드 함수
def load_texts(file_paths):
    data = {}
    for key, path in file_paths.items():
        with open(path, 'r', encoding='utf-8') as f:
            data[key] = f.read()
    return data

# 카테고리 로드 함수
def load_categories(file_paths):
    categories = []
    for path in file_paths:
        with open(path, 'r', encoding='utf-8') as f:
            categories.append(f.read())
    return categories

# 데이터 로드
text_data = load_texts(file_paths)
categories = load_categories(category_files)

# 데이터 확인
for key, content in text_data.items():
    print(f"{key} 일부:\n", content[:50])

print("category1 데이터 일부 (1부터 17까지):")
for i, category in enumerate(categories, start=1):
    print(f"문서 {i}: {category[:50]}")
# Out:
# 2015년 데이터 일부:
#  ns      문학으로 보는 시 간
#
# 다음 시에서 화자가 무엇을 후회하고 있는지 생각하며
# 2022년 데이터 일부:
#
# 생활 속의
#
# 환경
#
# 기념일
#
# 4월 4일
#
# 종이 안 쓰는 날
#
# 환경 기념일은 환경을 생각하
# category1 데이터 일부 (1부터 17까지):
# 문서 1: 1. 모든 곳에서 모든 형태의 빈곤 종식
#
# 1.1 2030년까지 현재 기준으로 하루에 $1
# 문서 2: 2. 기아 종식, 안전하고 영양이 개선된 식량 달성, 지속가능한 농업 장려
#
# 2.1 203
# 문서 3: 3. 모든 연령층을 위한 건강한 삶 보장과 웰빙 증진
#
# 3.1 2030년까지 전 세계 산모
# 문서 4: 4. 포용적이고 공평한 양질의 교육보장과 모두를 위한 평생학습 기회 증진
#
# 4.1 2030
# 문서 5: 5. 성평등 달성과 모든 여성 및 여아의 권익신장
#
# 5.1 모든 곳에서 여성 및 여아를 대
# 문서 6: 6. 모두를 위한 물과 위생의 이용가능성과 지속가능한 관리 보장
#
# 6.1 2030년까지 모
# 문서 7: 7. 모두를 위한 적정가격의 신뢰할 수 있고 지속가능하며 현대적인 에너지에 대한 접근 보장
# 문서 8: 8. 지속적&#65381;포용적&#65381;지속가능한 경제성장, 완전하고 생산적인 고용과
# 문서 9: 9. 회복력 있는 사회기반시설 구축, 포용적이고 지속가능한 산업화 증진과 혁신 도모
#
# 9.
# 문서 10: 10. 국내 및 국가 간 불평등 감소
#
# 10.1 2030년까지 하위 40% 인구의 소득성장
# 문서 11: 11. 포용적이고 안전하며 회복력 있고 지속가능한 도시와 주거지 조성
#
# 11.1 2030년
# 문서 12: 12. 지속가능한 소비와 생산 양식의 보장
#
# 12.1 개발도상국의 발전 상황과 역량을 고려
# 문서 13: 13. 기후변화와 그로 인한 영향에 맞서기 위한 긴급 대응
#
# 13.1 모든 국가에서 기후
# 문서 14: 14. 지속가능발전을 위하여 대양, 바다, 해양자원의 보전과 지속가능한 이용
#
# 14.1 2
# 문서 15: 15. 육상생태계 보호, 복원 및 지속가능한 이용 증진, 지속가능한 산림 관리, 사막화 방
# 문서 16: 16. 지속가능발전을 위한 평화롭고 포용적인 사회 증진, 모두에게 정의 보장과 모든 수준에
# 문서 17: 17. 이행수단 강화와 지속가능발전을 위한 글로벌 파트너십 재활성화
#
# 17.1 세금 및 기

# %%
import re
from konlpy.tag import Komoran

# Komoran 형태소 분석기 초기화
komoran = Komoran()

# 불용어 리스트를 공백으로 설정 (필요시 추가 가능)
stopwords = ['소비자']

def preprocess_nouns(text, stopwords=[]):
    """
    텍스트에서 한글 명사만 추출하고, 공백 및 줄바꿈 제거, 불용어 처리.
    """
    try:
        # 특수문자 및 공백 제거
        text = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣]', ' ', text)  # 한글 이외 제거 후 공백으로 대체
        text = re.sub(r'\s+', ' ', text).strip()  # 연속 공백 제거 및 양끝 공백 제거

        # 명사 추출
        nouns = komoran.nouns(text)

        # 불용어 제거
        filtered_nouns = [noun for noun in nouns if noun not in stopwords]

        # 결과를 공백으로 연결
        return ' '.join(filtered_nouns)
    except Exception as e:
        print(f"전처리 중 오류 발생: {e}")
        return ""

# %%
# 텍스트 전처리
preprocessed_texts = {key: preprocess_nouns(content, stopwords) for key, content in text_data.items()}
preprocessed_categories = [preprocess_nouns(category, stopwords) for category in categories]

# 결과 확인
print("2015년 데이터 전처리 결과:\n", preprocessed_texts["2015년 데이터"][:100])
print("2022년 데이터 전처리 결과:\n", preprocessed_texts["2022년 데이터"][:100])
print("카테고리 데이터 전처리 결과 (1부터 17까지):")
for i, category in enumerate(preprocessed_categories, start=1):
    print(f"문서 {i} 전처리 결과: {category[:100]}")
# Out:
# 2015년 데이터 전처리 결과:
#  문학 시 간 다음 시 화자 후회 생각 시 순간 꽃봉오리 인 것 정현종 후회 그때 일 노다지 도 그때 그사람 그때 물건 노다지 도 말 귀 벙어리 귀머거리 순간 사랑 것 순간 꽃봉오리
# 2022년 데이터 전처리 결과:
#  생활 속 환경 기념일 월 일 종이 날 환경 기념일 환경 생각 행동 지정 날 환경 보호 자원 순환 리가 참여 수 환경 기념일 생활 자원 생활 환경 중 등기 견본 오후 월 일 세계 차
# 카테고리 데이터 전처리 결과 (1부터 17까지):
# 문서 1 전처리 결과: 곳 형태 빈곤 종식 년 기준 하루 미만 사람 곳 절대 빈곤 인구 근절 년 국가 정의 측면 연령 남녀 아동 빈곤 인구 비율 최소한 절반 사회 안전망 포함 모두 국가 사회 보호 체제
# 문서 2 전처리 결과: 기아 종식 안전 영양 개선 식량 달성 지속 농업 장려 년 기아 종식 영유아 포함 사람 빈곤 계층 연중 안전 영양가 식량 접근 보장 년 미만 아동 발육 부진 체력 저하 국제 합의 목
# 문서 3 전처리 결과: 연령 건강 삶 보장 웰빙 증진 년 세계 산모 사망 비율 건의 생존 출산 당 건 미만 감소 년 신생아 미만 아동 예방 사망 종식 국가 신생아 사망 건의 생존 출산 당 건 미만 사망
# 문서 4 전처리 결과: 포용 공평 양질 교육 보장 모두 평생 학습 기회 증진 년 여아 남아 효과 학습 성과 수 공평 양질 무상 초등 교육 중등 교육 이수 보장 년 여아 남아 양질 영유아 발달 교육 보육
# 문서 5 전처리 결과: 성 평등 달성 여성 여아 권익 신장 곳 여성 여아 대상 형태 차별 인신매매 성 착취 기타 유형 착취 포함 공적 사적 영역 여성 여아 대상 형태 폭력 조혼 강제 결혼 여성 할례 등
# 문서 6 전처리 결과: 모두 물 위생 이용 지속 관리 보장 년 모두 적정 가격 안전 식수 보편 공평 접근 달성 년 여성 여아 상황 사람 요구 주의 모두 공평 공중위생 개인 위생 접근 달성 야외 배변 근절
# 문서 7 전처리 결과: 모두 적정 가격 신뢰 수 지속 현대 에너지 접근 보장 년 적정 가격 신뢰 수 현대 에너지 서비스 보편 접근 보장 년 세계 에너지원 구성 재생 에너지 비율 증대 년 세계 에너지 효율
# 문서 8 전처리 결과: 지속 포용 지속 경제성장 완전 생산 고용 모두 양질 일자리 증진 국가 상황 인당 소득 증가 유지 빈국 경우 연간 국내 총생산 성장률 최소 로 유지 부가가치 산업 노동 집약 산업 중
# 문서 9 전처리 결과: 회복 력 사회 기반 시설 구축 포용 지속 산업화 증진 혁신 도모 모두 적정 가격 공평 접근 중점 경제 발전 인류 웰빙 지원 지역 국경 사회 기반 시설 포함 양질 신뢰 수 지속 복원
# 문서 10 전처리 결과: 국내 국가 간 불평등 감소 년 하위 인구 소득 성장 국가 평균 수준 점진 달성 유지 년 나이 성별 장애 여부 인종 민족 출신 종교 경제 기타 지위 사람 사회 경제 정치 포용 강화
# 문서 11 전처리 결과: 포용 안전 회복 력 지속 도시 주거지 조성 년 모두 안전 적정 가격 주택 기초 서비스 접근 보장 빈민가 환경 개선 년 계층 여성 아동 장애인 고령자 필요 주의 대중교통 확대 모두
# 문서 12 전처리 결과: 지속 소비 생산 양식 보장 개발도상국 발전 상황 역량 고려 선진국 주도 지속 소비 생산 양식 개년 계획 국가 이행 년 천연자원 지속 관리 효율 사용 달성 년 유통 수준 세계 인구
# 문서 13 전처리 결과: 기후 변화 영향 긴급 대응 국가 기후 관련 위험 자연재해 회복 력 과 적응력 강화 기후 변화 대응조치 국가 정책 전략 계획 통합 기후 변화 완화 적응 영향 감소 조기 경보 등 교육
# 문서 14 전처리 결과: 지속 가능 발전 대양 바다 해양 자원 보전 지속 이용 년 해양 쓰레기 영양 염류 오염 포함 육상 활동 발생 종류 해양 오염 예방 상당 수준 년 악영향 회복 력 강화 방법 포함 해양
# 문서 15 전처리 결과: 육상 생태계 보호 복원 지속 이용 증진 지속 산림 관리 사막화 방지 토지 중지 회복 생물 다양성 손실 중단 년 국제 협정 의무 육지 내륙 담수 생태계 서비스 산림 습지 산지 건조지
# 문서 16 전처리 결과: 지속 가능 발전 평화 포용 사회 증진 모두 정 보장 수준 효과 책임 포용 제도 구축 곳 형태 폭력 폭력 사망률 감소 아동 학대 착취 매매 형태 폭력 고문 종식 국내 국제 차원 법치
# 문서 17 전처리 결과: 이행 수단 강화 지속 가능 발전 글로벌 파트너십 재활 성화 세금 기타 수입 징수 국내 역량 개선 개도국 국제 지원 등 국내 재원 동원 강화 선진국 개발도상국 공적 개발원조 규모 국

# %%
# 4. 전처리된 텍스트들을 공백 기준으로 토큰화
tokenized_texts = {key: text.split() for key, text in preprocessed_texts.items()}
tokenized_categories = [category.split() for category in preprocessed_categories]

# 5. 결과 확인
print("2015년 데이터 전처리 및 토큰화 결과:\n", tokenized_texts["2015년 데이터"])
print("\n2022년 데이터 전처리 및 토큰화 결과:\n", tokenized_texts["2022년 데이터"])
print("\n카테고리 데이터 토큰화 결과:")
for i, tokens in enumerate(tokenized_categories, start=1):
    print(f"문서 {i} 토큰화 결과: {tokens}")
# Out:
# 2015년 데이터 전처리 및 토큰화 결과:
#  ['문학', '시', '간', '다음', '시', '화자', '후회', '생각', '시', '순간', '꽃봉오리', '인', '것', '정현종', '후회', '그때', '일', '노다지', '도', '그때', '그사람', '그때', '물건', '노다지', '도', '말', '귀', '벙어리', '귀머거리', '순간', '사랑', '것', '순간', '꽃봉오리', '것', '열심', '꽃봉오리', '것', '시간', '후회', '경험', '이야기', '합리', '자원', '관리', '창의', '융합', '발전소', '청소년', '의자', '원', '관리', '생활', '자원', '관리', '문제', '생활', '자원', '중', '청소년기', '것', '시간', '자원', '이다', '시', '간', '자원', '관리', '시간', '효율', '사용', '하루', '시간', '사용', '내용', '분류', '것', '생활시간', '생활시간', '생리', '생활', '성취', '기준', '생활', '자원', '특성', '이해', '자신', '의', '상황', '생활', '자원', '관리', '문제', '분석', '삶의', '질', '향상', '수', '방법', '탐색', '실천', '생리', '생활시간', '시간', '노동', '생활시간', '여가', '생활시간', '수', '청소년기', '건강', '안정', '생활', '가지', '생활시간', '사용', '조화', '균형', '여가', '생활', '시간', '생명', '건강', '유지', '활동', '데', '필요', '수입', '일', '시간', '가정생활', '가사', '힘', '충전', '시간', '노동', '시간', '학업', '사용', '시간', '수면', '식사', '목욕', '몸단장', '용변', '휴식', '의료', '등', '출퇴근', '근무', '조리', '설거지', '자녀', '청소', '생리', '생활시간', '노동', '생활시간', '제외', '시간', '자신', '자아실현', '발전', '위', '자유', '사용', '시간', '자신', '생각', '자원', '표', '자원', '표', '생활', '자원', '특성', '위', '생명', '건강', '유지', '욕구', '충족', '목표', '사용', '자원', '생활', '자원', '생활', '자원', '미', '가정', '활동', '통학', '수업', '숙제', '등', '운동', '교양', '여행', '오락', '취미', '활동', '봉사', '활동', '등', '사용', '삶의', '질', '수', '균형', '생활', '삶의', '질', '향상', '수', '생활', '자원', '효율', '관리', '것', '생활', '자원', '종류', '특성', '생활', '자원', '인적', '자원', '물', '자원', '수', '원', '시간', '구매', '가치', '목록', '가치', '가치', '구입', '금액', '학급', '경매', '진행', '사랑', '사람', '행복', '지', '시간', '자아', '발전', '지식', '습득', '시간', '사람', '위해', '봉사', '시간', '인적', '자원', '의미', '개인', '능력', '특성', '자원', '종류', '시간', '건강', '지식', '기술', '등', '특성', '눈', '양', '과', '측정', '개인', '노력', '계발', '발전', '수', '물', '자원', '의미', '형태', '자원', '종류', '금전', '음식', '물품', '공간', '등', '특성', '양', '질', '측정', '사용', '양이', '없어', '진다', '개인', '가족', '소유', '사용', '건강', '을', '위해', '운동', '시간', '가족', '음식', '아이', '시간', '즐거움', '휴식', '오락', '여행', '시간', '경제', '안정', '일', '시간', '심리', '평', '안함', '수', '종교', '생활', '시간', '돈', '수', '사람', '수', '양의', '시간', '상황', '자원', '사용', '번', '수', '하루', '시간', '눈', '시계', '이용', '양', '흐름', '측정', '수', '저장', '수', '친구', '사교', '시간', '자신', '모습', '몸단장', '시간', '가치', '생각', '시간', '이유', '사고', '구입', '가치', '시간', '자원', '특성', '중', '가지', '관련', '속담', '명언', '이야기', '합리', '자원', '관리', '가치', '생각', '시간', '때', '것', '포기', '것', '청소년', '자원', '관리', '청소년', '시간', '관리', '방법', '시간', '관리', '자신', '목표', '시간', '사용', '것', '계획', '계획', '실천', '뒤', '결과', '평가', '과', '정', '말', '청소년', '시간', '삶', '목표', '달성', '데', '필요', '자원', '청소년기', '시간', '가치', '을', '시간', '효율', '관리', '시간', '관리', '학업', '여가', '생활', '등', '효과', '관리', '수', '여유', '균형', '생활', '수', '시', '저녁', '분', '차', '관동', '만', '과학', '책', '권', '지', '시간', '계획', '때', '시간', '작성', '등', '자신', '시간', '사용', '파악', '여', '시간', '사용', '습관', '사용', '시간', '파악', '다음', '일', '우선순위', '후', '연간', '월간', '주간', '하루', '계획', '목표', '시간', '계획', '계획', '일', '실천', '효과', '시간', '관리', '시간', '계획', '실천', '노력', '과', '의지', '필요', '실천', '계획', '검토', '계획', '로', '진행', '때', '이유', '생각', '대처', '방안', '마련', '실천', '과정', '예상', '상황', '발생', '때', '융통', '계획', '수정', '한다', '시', '간', '계획', '실천', '후', '계획', '실행', '문제', '시간', '관리', '결과', '평가', '만일', '평가', '결과', '만족', '유', '계획', '수정', '평가', '결과', '바탕', '기존', '계획', '수정', '다음', '계획', '우', '데', '반영', '평가', '기준', '목표', '달성', '우선순위', '계획', '계획', '실천', '생활시간', '균형', '개선', '점', '목표', '순위', '일', '순위', '긴급', '일', '학업', '관리', '여가', '관리', '효과', '시간', '관리', '목표', '도', '목표', '때', '달성', '기간', '년', '이상', '장기', '목표', '일', '주일', '개월', '등', '단기', '목표', '구분', '목표', '구체', '순위', '사람', '부탁', '일', '학습', '목표', '실천', '학습량', '정', '실천', '자신', '수준', '진도', '학습', '주도', '학습', '시간', '집중', '능률', '시간대', '규칙', '학습', '수', '계획', '공부', '후', '휴식', '청소년기', '여가', '생활', '삶의', '질', '향상', '발전', '도움', '여', '효과', '관리', '여가', '생활', '시간', '배분', '생활시간', '균형', '을', '능동', '여가', '생활', '즐거움', '자신', '적', '성', '과', '소', '을', '발', '견', '하', '여', '자', '기', '계', '발', '도', '되', '도', '록', '측정', '수', '실현', '것', '구체', '마감일', '정리', '생활시간', '중', '생명', '건강', '유지', '활동', '데', '필요', '힘', '충전', '시간', '하', '시간', '자원', '특성', '이야기', '청소년기', '시간', '관리', '점', '이야기', '청 ...
#
# 2022년 데이터 전처리 및 토큰화 결과:
#  ['생활', '속', '환경', '기념일', '월', '일', '종이', '날', '환경', '기념일', '환경', '생각', '행동', '지정', '날', '환경', '보호', '자원', '순환', '리가', '참여', '수', '환경', '기념일', '생활', '자원', '생활', '환경', '중', '등기', '견본', '오후', '월', '일', '세계', '차', '날', '월', '일', '음식물', '쓰레기', '날', '환경', '보호', '날', '생각', '소통', '협력', '가정', '중', '등기', '견본', '오후', '생활', '자원', '순환', '과정', '성취', '기준', '생활', '자원', '종류', '특성', '순환', '과', '정', '이해', '의식주', '자원', '관리', '인식', '무인도', '살아남기', '필요', '것', '생활', '자원', '종류', '특성', '리가', '생명', '유지', '가지', '활동', '데', '필요', '것', '생활', '자', '원', '생활', '자원', '인적', '자원', '물', '자원', '구분', '수', '사람', '생활', '자원', '종류', '양은', '때문', '자신', '생활', '자원', '의', '특성', '활용', '삶의', '질', '수', '물', '자원', '금전', '시간', '건강', '의미', '형태', '자원', '종류', '금전', '음식', '옷', '생활', '공간', '등', '특성', '형태', '양', '질', '측정', '사용', '양이', '없어', '진다', '개인', '가족', '소유', '사용', '음식', '옷', '기술', '의미', '개인', '가족', '능력', '특성', '종류', '시간', '건강', '기술', '지식', '등', '특성', '눈', '양', '질', '측정', '개인', '노력', '계발', '발전', '수', '물', '자원', '효용', '생활', '공간', '인적', '자원', '지식', '생활', '자원', '생활', '환경', '중', '등기', '견본', '오후', '리가', '사용', '자원', '대부분', '폐기물', '과정', '은', '환경', '문제', '발생', '기후', '위기', '대응', '환경', '자', '원', '순환', '이용', '수', '생활', '자원', '순환', '자원', '생산', '소비', '관리', '과정', '폐기물', '발생', '최대한', '사용', '발생', '폐기물', '을', '재활용', '재생', '이용', '것', '말', '생활', '자원', '순환', '과정', '생활', '속', '자원', '순환', '과정', '폐기물', '발생', '원천', '재활용', '제품', '생산', '생산', '자원', '가치', '미래', '폐기물', '재생', '재활용', '촉진', '친환경', '소비', '폐기', '물', '발생', '최소', '생활', '자원', '순환', '과정', '소비', '친환경', '소비', '폐기물', '발생', '최소', '관리', '폐기물', '매립', '소각', '부담금', '부과', '폐기물', '배출', '수거', '선별', '체계', '개', '선', '자원', '환경', '생각', '일상', '속', '리', '행동', '지구', '생태', '영향', '사실', '생활', '자원', '순환', '동참', '생활', '자원', '순환', '위', '실천', '방법', '다음', '가지', '활용', '자원', '순환', '활용', '분리', '수거', '것', '의미', '예', '분리', '가지', '원칙', '사용', '번', '사용', '자원', '절', '재사용', '뜻', '예', '이면', '지', '시', '불필요', '것', '쓰레기', '낭비', '자원', '오염', '물질', '최소', '것', '의미', '예', '텀블러', '사용', '필요', '물건', '거절', '필요', '환경', '파괴', '물', '건', '구매', '대신', '재사용', '물건', '사용', '것', '말', '예', '탄소', '인증', '제품', '사용', '생활', '자원', '순환', '가지', '실천', '방법', '분리', '배출', '가지', '원칙', '생활', '자원', '순환', '과정', '중', '등기', '견본', '오후', '의식주', '자원', '관리', '인간', '데', '의식주', '생활', '필수', '의식주', '생활', '상', '품', '산지', '생산', '유통', '소비', '폐기', '일련', '과정', '지', '자원', '사용', '과정', '온실', '가스', '탄소', '배출', '기후', '위기', '가속', '환경', '오염', '물질', '쓰레기', '환경', '문제', '발생', '현대', '사회', '편리', '풍요', '생활', '대량', '생산', '분별', '소비', '과거', '자원', '에너지', '사용', '인간', '자연', '공존', '생활', '자원', '환경', '영향', '인식', '순환', '고려', '의식주', '자원', '관리', '필요', '과거', '현재', '의식주', '생활', '변화', '과거', '의', '생활', '천연', '소재', '옷감', '것', '합성', '섬유', '등장', '옷', '대량', '생산', '수', '옷', '소비', '대부분', '생산', '식품', '이동', '거리', '음식물', '쓰레기', '발생', '식생활', '먹거리', '식', '배달', '서비스', '활성', '음식물', '쓰레기', '발생', '자연', '수', '재료', '활용', '집', '생활', '용품', '소비', '주생활', '고층', '건물', '때', '철근', '시멘트', '등', '자원', '사용', '생활', '용품', '소비', '폐기물', '발생', '활동', '배달', '음식', '인해', '발생', '쓰레기', '종류', '것', '생각', '지식', '이해', '생명', '유지', '가지', '활동', '데', '필요', '것', '주도', '정리', '과정', '기능', '생활', '자원', '순환', '과정', '가치', '태도', '의식주', '자원', '관리', '이야기', '생활', '자원', '생활', '환경', '중', '등기', '견본', '오후', '세상', '환경', '리가', '수', '삶', '만큼', '환경', '오염', '지구', '온난화', '생활', '속', '환경', '수', '일', '것', '제로', '운동', '용기', '용기', '자', '뜻', '스웨덴어', '플로', '카', '업', '과', '뜻', '영어', '조깅', '의', '합성어', '레', '것', '말', '년', '스웨덴', '처음', '시작', '하', '여', '세계', '확산', '문화', '운동', '자', '보호', '활동', '개념', '최근', '건강', '여가', '지구', '수', '점', '사람', '관심', '참여', '용기', '내', '린지', '음식', '포장', '발생', '쓰레기', '다회', '용기', '음식', '포장', '운동', '말', '제로', '말', '것', '쓰레기', '의미', '쓰레기', '배출', '일회용품', '사용', '재활용', '소', '재', '대체', '쓰레기', '배출량', '것', '목', '표', '생각', '더하기', '환경', '학교', '실천', '수', '것', '생각', '생활', '자원', '순환', '과정', '중', '등기', '견본', '오후', '의식주', '생활', '자원', '생산', '폐기', '성취', '기준', '의식주', '생활', '자원', '생산', '폐기', '과', '정', '탐색', '일상생활', '의식주', '생활', '자원', '선택', '과정', '결과', '성찰', '옷', '활용', '옷', '때', '옷', '산다', '옷', '용도', '정리', '보관', '위', '그림', '친환경', '의', '생활', '것', ...
#
# 카테고리 데이터 토큰화 결과:
# 문서 1 토큰화 결과: ['곳', '형태', '빈곤', '종식', '년', '기준', '하루', '미만', '사람', '곳', '절대', '빈곤', '인구', '근절', '년', '국가', '정의', '측면', '연령', '남녀', '아동', '빈곤', '인구', '비율', '최소한', '절반', '사회', '안전망', '포함', '모두', '국가', '사회', '보호', '체제', '조치', '이행', '년', '빈곤', '계층', '실질', '보장', '달성', '년', '남성', '여성', '빈곤', '계층', '경제', '자원', '동등', '권리', '기초', '공공', '서비스', '토지', '기타', '유형', '자산', '유산', '천연자원', '적정', '신기술', '소액', '금융', '포함', '금융', '서비스', '오너', '통제', '접근', '동등', '권리', '것', '보장', '년', '빈곤', '계층', '회복', '력', '구축', '극한', '기후', '관련', '사건', '기타', '경제', '사회', '환경', '충격', '재난', '노출', '감소', '개도국', '최', '빈', '개도국', '측면', '빈곤', '종식', '프로그램', '정책', '이행', '수', '예측', '수단', '제공', '개발', '협력', '증진', '등', '원천', '자원', '상당', '동원', '보장', '빈곤', '퇴치', '활동', '투자', '증대', '빈곤', '친화', '성', '인지', '개발', '전략', '기반', '국가', '지역', '국제', '차원', '정책', '프레임', '워크', '형성']
# 문서 2 토큰화 결과: ['기아', '종식', '안전', '영양', '개선', '식량', '달성', '지속', '농업', '장려', '년', '기아', '종식', '영유아', '포함', '사람', '빈곤', '계층', '연중', '안전', '영양가', '식량', '접근', '보장', '년', '미만', '아동', '발육', '부진', '체력', '저하', '국제', '합의', '목표', '달성', '청소년기', '소녀', '임산부', '모유', '수유', '여성', '노년', '영양', '필요', '성명', '년', '형태', '영양', '결핍', '년', '토지', '기타', '생산', '자원', '투입', '요소', '지식', '금융', '서비스', '시장', '부가가치', '창출', '농업부', '문', '고용', '기회', '안전', '평등', '접근', '등', '영세', '농산물', '생산자', '여성', '토착민', '가족', '농', '목축', '민', '어업인', '농업', '생산성', '소득', '배로', '년', '지속', '식량', '생산', '체제', '확보', '한편', '생산성', '생산량', '증대', '생태계', '유지', '도움', '기후', '변화', '기상', '현상', '가뭄', '홍수', '기타', '재난', '적응력', '강화', '점진', '토지', '토양', '질', '개선', '회복', '력', '농업', '원칙', '이행', '년', '국가', '지역', '국제', '수준', '관리', '종자', '식물', '은행', '포함', '씨앗', '농작물', '가축', '관련', '야생', '종의', '유전', '다양성', '유지', '국제', '합의', '대로', '유전자', '자원', '전통', '지식', '활용', '접근', '촉진', '이익', '공평', '공정', '공유', '보장', '개발도상국', '빈국', '농업', '분야', '생산', '역량', '강화', '국제', '협력', '증진', '농촌', '사회', '기반', '시설', '농업', '연구', '지원', '서비스', '기술', '개발', '식물', '가축', '유전자은행', '설립', '투자', '확대', '도하', '개발', '라운드', '의', '지침', '형태', '농업', '수출', '보조금', '동등', '효과', '수출', '조치', '병행', '제거', '등', '세계', '농산물', '시장', '무역', '제한', '왜곡', '예방', '식료품', '시장', '파생상품', '시장', '기능', '보장', '수', '방안', '채택', '과도', '식량', '가격', '변동', '제한', '수', '식량', '저장', '시장', '정보', '적시', '접근', '원활', '조치', '채택']
# 문서 3 토큰화 결과: ['연령', '건강', '삶', '보장', '웰빙', '증진', '년', '세계', '산모', '사망', '비율', '건의', '생존', '출산', '당', '건', '미만', '감소', '년', '신생아', '미만', '아동', '예방', '사망', '종식', '국가', '신생아', '사망', '건의', '생존', '출산', '당', '건', '미만', '사망', '건의', '생존', '출산', '당', '건', '감축', '것', '지향', '년', '감염병', '결핵', '말라리아', '소외', '열대', '질환', '유행', '종식', '간염', '수', '인성', '질병', '기타', '감염', '질병', '퇴치', '년', '예방', '치료', '전염', '질병', '조기', '사망', '분', '감축', '정신건강', '복리', '증진', '마약', '알코올', '포함', '약물', '오남용', '예방', '치료', '강화', '년', '세계', '교통사고', '사망', '상해', '절반', '년', '가족계획', '정보', '교육', '성과', '재생산', '건강', '국가', '전략', '계획', '통합', '것', '포함', '성과', '재생산', '보건', '서비스', '보편', '접근', '보장', '재무', '위험관리', '양질', '필수', '보건', '서비스', '접근', '양질', '안전', '효과', '적정', '가격', '필수', '약품', '백신', '접근', '보장', '모두', '보편', '의료', '보장', '을', '달성', '년', '유해', '화학', '물질', '대기', '수질', '토지', '공해', '오염', '사망', '질병', '건수', '감소', '국가', '세계', '건강', '기구', '담배', '규제', '기본', '협약', '의', '이행', '강화', '개발도상국', '영향', '감염', '감염', '질병', '백신', '의약품', '연구개발', '지원', '공중', '보건', '보호', '사람', '의약품', '접근', '보장', '무역', '관련', '지적', '재산권', '협정', '조항', '활용', '수', '개발도상국', '권리', '확인', '협정', '공중', '보건', '도하', '선언', '적정', '가격', '필수', '의약품', '백신', '접근', '제공', '개발도상국', '빈국', '군소', '도서', '개도국', '보건', '재원', '보건', '인력', '채용', '계발', '훈련', '보유', '확대', '국가', '개도국', '국가', '세계', '보건', '위험', '조기', '경보', '위험', '감축', '관리', '역량', '강화']
# 문서 4 토큰화 결과: ['포용', '공평', '양질', '교육', '보장', '모두', '평생', '학습', '기회', '증진', '년', '여아', '남아', '효과', '학습', '성과', '수', '공평', '양질', '무상', '초등', '교육', '중등', '교육', '이수', '보장', '년', '여아', '남아', '양질', '영유아', '발달', '교육', '보육', '취학', '교육', '접근', '보장', '초등', '교육', '준비', '수', '년', '여성', '남성', '적정', '비용', '양질', '기술', '교육', '직업', '교육', '대학', '포함', '고등', '교육', '평등', '접근', '보장', '년', '취업', '양질', '일자리', '창업', '활동', '필요', '전문', '직업', '기술', '등', '기술', '청소년', '성인', '수', '실질', '년', '교육', '성', '불평등', '해소', '장애인', '토착민', '상황', '아동', '포함', '계층', '수준', '교육', '직업훈련', '평등', '접근', '보장', '년', '청소년', '상당수', '성인', '남녀', '문해', '력', '수리', '력', '성취', '보장', '년', '학습자', '지속', '가능', '발전', '지속', '가능', '생활', '방식', '인권', '성', '평등', '평화', '비폭력', '문화', '증진', '세계', '시민', '의식', '문화', '다양성', '지속', '가능', '발전', '문화', '기여', '교육', '지속', '가능', '발전', '증진', '필요', '지식', '기술', '습득', '보장', '아동', '장애', '성', '인지', '교육', '시설', '건립', '개선', '모두', '안전', '비폭력', '포용', '효과', '학습', '환경', '제공', '년', '세계', '개발도상국', '빈국', '군소', '도서', '개발국', '아프리카', '국가', '등', '선진국', '기타', '개발도상국', '직업훈련', '정보통신기술', '과학', '기술', '공학', '분야', '포함', '고등', '교육', '등록', '지원', '장학금', '실질', '확대', '년', '개발도상국', '빈국', '군소', '도서', '개발국', '교사', '훈련', '국제', '협력', '등', '자격', '교사', '공급', '실질']
# 문서 5 토큰화 결과: ['성', '평등', '달성', '여성', '여아', '권익', '신장', '곳', '여성', '여아', '대상', '형태', '차별', '인신매매', '성', '착취', '기타', '유형', '착취', '포함', '공적', '사적', '영역', '여성', '여아', '대상', '형태', '폭력', '조혼', '강제', '결혼', '여성', '할례', '등', '유해', '관행', '공공', '서비스', '사회', '기반', '시설', '사회', '보호', '정책', '제공', '국가', '가구', '가족', '책임', '분담', '증진', '무상', '가사', '노동', '인정', '가치', '인식', '정치', '경제', '공공', '부문', '의사', '결정', '과정', '여성', '완전', '효과', '참여', '리더십', '평등', '기회', '보장', '국제', '인구', '개발', '회의', '행동', '계획', '베이징', '행동', '강령', '검토', '회의', '결과', '문서', '합의', '대로', '성과', '재생산', '건강', '재생산', '보편', '접근', '보장', '여성', '경제', '자원', '평등', '권리', '토지', '기타', '유형', '자산', '금융', '서비스', '유산', '천연자원', '오너', '통제', '접근', '평등', '권리', '부여', '수', '국내법', '개혁', '시행', '여성', '권익', '신장', '증진', '핵심', '기술', '정보통신기술', '이용', '강화', '수준', '성', '평등', '여성', '여아', '권익', '신장', '증진', '정책', '시행', '법안', '채택', '강화']
# 문서 6 토큰화 결과: ['모두', '물', '위생', '이용', '지속', '관리', '보장', '년', '모두', '적정', '가격', '안전', '식수', '보편', '공평', '접근', '달성', '년', '여성', '여아', '상황', '사람', '요구', '주의', '모두', '공평', '공중위생', '개인', '위생', '접근', '달성', '야외', '배변', '근절', '년', '오염', '저감', '유해', '물질', '투기', '근절', '배출', '최소', '미', '처리', '폐수', '비율', '반감', '세계', '재활용', '안전', '재사용', '증진', '수질', '개선', '년', '부문', '물', '사용', '효율', '증가', '물', '부족', '대응', '담수', '지속', '공급', '보장', '물', '부족', '고통', '사람', '수', '감소', '년', '경우', '국경', '협력', '등', '수준', '통합', '수자원', '관리', '이행', '년', '숲', '습지', '강', '지하수', '호수', '포함', '물', '관련', '생태계', '보호', '복원', '년', '집', '수', '담수', '물', '효율', '폐수', '처리', '재활용', '재사용', '기술', '포함', '물', '위생', '관련', '활동', '프로그램', '개도국', '역량', '강화', '지원', '국제', '협력', '확대', '물', '위생', '관리', '개선', '지역', '사회', '참여', '지원', '강화']
# 문서 7 토큰화 결과: ['모두', '적정', '가격', '신뢰', '수', '지속', '현대', '에너지', '접근', '보장', '년', '적정', '가격', '신뢰', '수', '현대', '에너지', '서비스', '보편', '접근', '보장', '년', '세계', '에너지원', '구성', '재생', '에너지', '비율', '증대', '년', '세계', '에너지', '효율', '배', '향상', '년', '재생', '에너지', '에너지', '효율', '선진', '청정', '화석', '연료', '기술', '등', '포함', '청정에너지', '연구', '기술', '개발', '접근', '촉진', '수', '국제', '협력', '강화', '에너지', '기반', '시설', '청정에너지', '기술', '투자', '증진', '년', '개도국', '최', '빈', '개도국', '군소', '도서', '개도국', '내륙', '개도국', '각국', '지원', '프로그램', '모두', '현대', '지속', '에너지', '서비스', '공급', '기반', '시설', '확대', '기술', '개선']
# 문서 8 토큰화 결과: ['지속', '포용', '지속', '경제성장', '완전', '생산', '고용', '모두', '양질', '일자리', '증진', '국가', '상황', '인당', '소득', '증가', '유지', '빈국', '경우', '연간', '국내', '총생산', '성장률', '최소', '로', '유지', '부가가치', '산업', '노동', '집약', '산업', '중점', '것', '포함', '산업', '다변', '기술', '발전', '혁신', '경제', '생산성', '향상', '달성', '생산', '활동', '양질', '일자리', '창출', '기업가', '정신', '창의성', '혁신', '지원', '개발', '지향', '정책', '진흥', '금융', '서비스', '접근', '확대', '포함', '규모', '비즈니스', '중소기업', '형성', '성장', '장려', '지속', '소비', '생산', '개년', '계획', '선진국', '주도', '소비', '생산', '세계', '자원', '효율', '년', '점진', '개선', '경제성장', '환경', '악화', '분리', '노력', '년', '청년', '장애인', '포함', '여성', '남성', '완전', '생산', '고용', '양질', '일자리', '동일', '가치', '노동', '동일', '임금', '달성', '년', '교육', '훈련', '참여', '실업', '상태', '청년', '비율', '강제', '노동', '현대판', '노예제', '인신매매', '근절', '소년병', '징집', '동원', '등', '포함', '형태', '아동', '노동', '금지', '종식', '보장', '즉각', '효과', '조치', '년', '형태', '아동', '노동', '이주', '노동자', '이주', '여성', '불안정', '고용', '상태', '노동자', '포함', '노동자', '노동권', '보호', '안전', '안정', '근로', '환경', '증진', '년', '지역', '고유문화', '특산품', '일자리', '창출', '기여', '지속', '가능한', '관광', '진흥', '정책', '개발', '이행', '모두', '은행', '보험', '금융', '서비스', '접근', '장려', '확대', '수', '국내', '금융', '기관', '역량', '강화', '빈국', '무역', '관련', '기술', '지원', '강화', '통합', '프레임', '워크', '등', '개발도상국', '빈국', '무역', '원조', '지원', '확대', '년', '청년', '고용', '글로벌', '전략', '개발', '운영', '국제', '노동', '기구', '세계', '고용', '협약', '을', '이행']
# 문서 9 토큰화 결과: ['회복', '력', '사회', '기반', '시설', '구축', '포용', '지속', '산업화', '증진', '혁신', '도모', '모두', '적정', '가격', '공평', '접근', '중점', '경제', '발전', '인류', '웰빙', '지원', '지역', '국경', '사회', '기반', '시설', '포함', '양질', '신뢰', '수', '지속', '복원력', '사회', '기반', '시설', '구축', '포용', '지속', '산업화', '증진', '년', '국가', '상황', '고용', '국내', '총', '생산', '산업', '비중', '증대', '빈국', '배', '증대', '개발도상국', '신용우', '대', '가치', '사슬', '시장', '통합', '포함', '규모', '산업체', '기타', '기업', '금융', '서비스', '접근', '향상', '년', '사회', '기반', '시설', '개선', '산업', '개편', '지속', '자원', '이용', '효율', '향상', '청정', '친환경', '기술', '산업', '프로세스', '채택', '확장', '국가', '각국', '역량', '행동', '과학', '연구', '강화', '년', '혁신', '장려', '명', '당', '연구개발', '종사자', '수', '증가', '공공', '민간', '연구개발', '지출', '증가', '등', '국가', '개도국', '산업', '분야', '기술', '역량', '향상', '아프리카', '국가', '최', '빈', '개도국', '내륙', '개도국', '군소', '도서', '개도국', '금융', '기술', '기능', '지원', '제공', '지속', '회복', '력', '사회', '기반', '시설', '개발', '촉진', '산업', '다변', '원자재', '부가가치', '창출', '등', '정책', '환경', '보장', '개도국', '국내', '기술', '개발', '연구', '혁신', '지원', '빈국', '정보통신기술', '접근', '증가', '년', '적정', '가격', '보편', '인터넷', '접근', '제공', '수', '노력']
# 문서 10 토큰화 결과: ['국내', '국가', '간', '불평등', '감소', '년', '하위', '인구', '소득', '성장', '국가', '평균', '수준', '점진', '달성', '유지', '년', '나이', '성별', '장애', '여부', '인종', '민족', '출신', '종교', '경제', '기타', '지위', '사람', '사회', '경제', '정치', '포용', '강화', '증진', '차별', '법규', '정책', '관례', '철폐', '관련', '법', '정책', '활동', '증진', '등', '노력', '평등', '기회', '보장', '결과', '불평등', '감소', '재정', '정책', '임금', '정책', '사회', '보호', '정책', '정책', '도입', '점진', '수준', '평등', '달성', '세계', '금융', '시장', '기구', '규제', '모니터링', '개선', '규제', '이행', '강화', '효과', '신뢰', '수', '책임', '합법', '기관', '글로벌', '국제', '경제', '금융', '기구', '의사', '결정', '개도국', '대표', '발언', '강화', '보장', '계획', '관리', '이주', '정책', '이행', '등', '질서', '안전', '정기', '책임감', '이주', '사람', '이동', '촉진', '세계무역기구', '협정', '개도국', '최', '빈', '개도국', '차등', '대우', '원칙', '이행', '국가', '계획', '프로그램', '수요', '국가', '최', '빈', '개도국', '아프리카', '국가', '군소', '도서', '개도국', '내륙', '개도국', '해외', '직접투자', '포함', '공적', '개발원조', '자금', '거래', '장려', '년', '주자', '송금', '비용', '미만', '비용', '초과', '송금', '경로', '철폐']
# 문서 11 토큰화 결과: ['포용', '안전', '회복', '력', '지속', '도시', '주거지', '조성', '년', '모두', '안전', '적정', '가격', '주택', '기초', '서비스', '접근', '보장', '빈민가', '환경', '개선', '년', '계층', '여성', '아동', '장애인', '고령자', '필요', '주의', '대중교통', '확대', '모두', '안전', '접근', '지속', '교통', '체제', '접근', '제공', '도로', '안전', '향상', '년', '국가', '포용', '지속', '도시화', '확대', '참여', '통합', '지속', '인간', '정주', '계획', '관리', '역량', '강화', '세계', '문화유산', '자연', '유산', '보호', '노력', '강화', '년', '빈곤', '계층', '보호', '주력', '물', '관련', '재난', '재난', '사망자', '피해자', '수', '재난', '직접', '경제', '손실', '글로벌', '국내', '총', '생산', '대비', '년', '기질', '도시', '생활', '폐기물', '기타', '폐기물', '관리', '주의', '도시', '인당', '부정', '환경', '영향', '년', '여성', '아동', '노인', '장애인', '안전', '포용', '접근', '공공', '녹지', '공간', '보편', '접근', '보장', '국가', '지역', '개발', '계획', '강화', '도시', '도시', '근교', '농촌', '지역', '간', '긍정', '경제', '사회', '환경', '연결', '지원', '년', '포용', '자원', '효율', '기후', '변화', '완화', '적응', '재난', '회복', '력', '통합', '정책', '계획', '채택', '이행', '도', '시와', '정', '주지', '수', '증대', '재난', '위험', '경감', '센다이', '프레임', '워크', '수준', '전체', '재난', '위험관리', '개발', '이행', '빈국', '현지', '자재', '사용', '지속', '회복', '력', '건물', '수', '재정', '기술', '지원']
# 문서 12 토큰화 결과: ['지속', '소비', '생산', '양식', '보장', '개발도상국', '발전', '상황', '역량', '고려', '선진국', '주도', '지속', '소비', '생산', '양식', '개년', '계획', '국가', '이행', '년', '천연자원', '지속', '관리', '효율', '사용', '달성', '년', '유통', '수준', '세계', '인구', '인당', '음식물', '쓰레기', '발생', '량', '절반', '출하', '후', '손실', '포함', '식품', '생산', '공급', '망', '발생', '식품', '손실', '감소', '년', '국제', '사회', '합의', '프레임', '워크', '근거', '화학', '물질', '폐기물', '친환경', '관리', '인간', '건강', '환경', '부정', '영향', '최소', '대기', '물', '토양', '배출', '년', '예방', '감축', '재활용', '재사용', '폐기물', '발생', '기업', '대기업', '다국적', '기업', '지속', '실천', '계획', '채택', '지속', '정보', '통합', '것', '장려', '국가', '정책', '우선순위', '지속', '공공', '조달', '시행', '촉진', '년', '사람', '자연', '조화', '지속', '발전', '생활양식', '정보', '인식', '보장', '개도국', '지속', '소비', '생산', '양식', '과학', '기술', '역량', '강화', '지원', '일자리', '창출', '지역', '문화', '특산품', '지속', '가능', '관광', '지속', '가능', '발전', '영향', '모니터링', '수단', '개발', '이행', '개발도상국', '특수', '필요', '여건', '고려', '빈곤', '영향', '공동체', '보호', '방식', '개발도상국', '발전', '부정', '영향', '최소', '보조금', '환경', '영향', '반영', '세제', '개혁', '환경', '유해', '보조금', '단계', '폐지', '등', '방법', '국가', '상황', '시장', '왜곡', '제거', '낭비', '소비', '조장', '효율', '화석', '연료', '보조금', '합리']
# 문서 13 토큰화 결과: ['기후', '변화', '영향', '긴급', '대응', '국가', '기후', '관련', '위험', '자연재해', '회복', '력', '과', '적응력', '강화', '기후', '변화', '대응조치', '국가', '정책', '전략', '계획', '통합', '기후', '변화', '완화', '적응', '영향', '감소', '조기', '경보', '등', '교육', '인식', '인적', '제도', '역량', '강화', '출자', '녹색', '기후', '기금', '의', '운영', '의미', '완화', '조치', '이행', '투명', '배경', '개도국', '수요', '년', '원천', '불', '공동', '동원', '목표', '유엔', '기후', '변화', '협약', '선진국', '당사국', '약속', '이행', '여성', '청년', '지역', '사회', '외', '사회', '약자', '주목', '최', '빈', '개도국', '군소', '도서', '국가', '기후', '변화', '관련', '효과', '계획', '관리', '역량', '향상', '메커니즘', '장려']
# 문서 14 토큰화 결과: ['지속', '가능', '발전', '대양', '바다', '해양', '자원', '보전', '지속', '이용', '년', '해양', '쓰레기', '영양', '염류', '오염', '포함', '육상', '활동', '발생', '종류', '해양', '오염', '예방', '상당', '수준', '년', '악영향', '회복', '력', '강화', '방법', '포함', '해양', '연안', '생태계', '지속', '관리', '보호', '건강', '생산', '해양', '조성', '복원', '조치', '시행', '수준', '과학', '협력', '강화', '해양', '산성화', '영향', '최소', '대응', '년', '최소한', '생물학', '특성', '결정', '최대', '지속', '생산량', '수준', '단기간', '어족', '자원', '회복', '효과', '어획', '규제', '남획', '불법', '비보고', '비규제', '어업', '파괴', '어업', '관행', '종식', '과학', '기초', '관리', '계획', '이행', '년', '국내법', '국제법', '부합', '방식', '가용', '최상', '과학', '정보', '기초', '연안', '해양', '최소', '보전', '개도국', '최', '빈', '개도국', '효과', '차등', '대우', '세계무역기구', '수산', '보조금', '협상', '필수', '부분', '것', '인지', '년', '과잉', '어획', '능력', '남획', '초래', '유형', '수산', '보조금', '금지', '불법', '비보고', '비규제', '어업', '초래', '보조금', '근절', '신규', '보조금', '도입', '제한', '년', '어업', '양식업', '관광', '지속', '가능', '관리', '등', '해양', '자원', '지속', '이용', '군', '서도', '서', '개도국', '최', '빈', '개도국', '경제', '이익', '증대', '군소', '도서', '개도국', '최', '빈', '개도국', '등', '개도국', '발전', '해양', '생물', '다양성', '기여도', '향상', '해양', '건강', '증진', '해양', '기술', '이전', '정부', '간', '해양학', '위원회', '의', '기준', '지침', '고려', '과학', '지식', '연구', '역량', '발전', '해양', '기술', '이전', '규모', '영세', '어업인', '해양', '자원', '시장', '접근', '수', '지원', '미래', '보고서', '번', '항', '환기', '해양', '해양', '자원', '보전', '지속', '이용', '법체계', '제시', '유엔', '해양법', '협약', '반영', '국제법', '이행', '해양', '해양', '자원', '보전', '지속', '이용', '강화']
# 문서 15 토큰화 결과: ['육상', '생태계', '보호', '복원', '지속', '이용', '증진', '지속', '산림', '관리', '사막화', '방지', '토지', '중지', '회복', '생물', '다양성', '손실', '중단', '년', '국제', '협정', '의무', '육지', '내륙', '담수', '생태계', '서비스', '산림', '습지', '산지', '건조지', '보존', '복원', '지속', '이용', '보장', '년', '세계', '형태', '산림', '지속', '관리', '이행', '도모', '개발', '산림', '파괴', '중단', '훼손', '산림', '복원', '신규', '조림', '재조림', '증대', '년', '사막화', '방지', '사막화', '가뭄', '홍수', '영향', '토지', '포함', '훼손', '토지', '토양', '복원', '토지', '훼손', '중립', '세계', '달성', '노력', '년', '지속', '가능', '발전', '필수', '혜택', '제공', '산림', '생태계', '수용', '력', '증진', '수', '생물', '다양성', '포함', '산지', '생태계', '보전', '보장', '자연', '서식지', '훼손', '행동', '생물', '다양성', '손실', '중지', '년', '멸종', '위기', '종', '보호', '멸종', '예방', '국제', '합의', '유전자원', '이용', '발생', '이익', '공정', '공평', '공유', '촉진', '유전자원', '접근', '장려', '보호', '동식물', '밀렵', '밀매', '종식', '행동', '불법', '야생', '동식물', '제품', '수요와', '공급', '대응', '년', '침입', '외래종', '유입', '조치', '도입', '육상', '수', '생태계', '영향', '우점', '종', '을', '통제', '제거', '년', '생태계', '생물', '다양성', '가치', '국가', '지역', '계획', '개발', '프로세스', '빈곤', '감소', '전략', '회계', '통합', '생물', '다양성', '생태계', '보전', '지속', '이용', '원천', '재원', '동원', '증대', '원천', '수준', '상당', '자원', '동원', '지속', '산림', '관리', '재원', '지원', '보전', '재조림', '등', '산림', '관리', '진척', '개도국', '인센티브', '제공', '지속', '생계', '기회', '추구', '지역', '공동체', '역량', '증진', '보호', '종의', '밀렵', '밀매', '방지', '노력', '지구', '지원', '강화']
# 문서 16 토큰화 결과: ['지속', '가능', '발전', '평화', '포용', '사회', '증진', '모두', '정', '보장', '수준', '효과', '책임', '포용', '제도', '구축', '곳', '형태', '폭력', '폭력', '사망률', '감소', '아동', '학대', '착취', '매매', '형태', '폭력', '고문', '종식', '국내', '국제', '차원', '법치', '증진', '정의', '평등', '접근', '모두', '보장', '년', '불법', '자금', '무기', '거래', '감소', '불법', '취득', '자산', '환수', '반환', '조치', '강화', '형태', '조직범죄', '퇴치', '형태', '부패', '뇌물', '감소', '효과', '책임', '투명', '제도', '단계', '기관', '구축', '호응', '포용', '참여', '대표', '의사', '결정', '단계', '보장', '개발도상국', '글로벌', '거버넌스', '제도', '기관', '참여', '확대', '강화', '년', '출생', '등록', '모두', '법', '지위', '부여', '국내법', '국제', '협정', '정보', '대중', '접근', '보장', '기본', '자유', '보호', '폭력', '예방', '테러', '범죄', '퇴치', '국제', '협력', '등', '단계', '역량', '개발', '국가', '관련', '제도', '강화', '개발도상국', '제도', '강화', '지속', '가능', '발전', '차별', '법규', '정책', '증진', '시행']
# 문서 17 토큰화 결과: ['이행', '수단', '강화', '지속', '가능', '발전', '글로벌', '파트너십', '재활', '성화', '세금', '기타', '수입', '징수', '국내', '역량', '개선', '개도국', '국제', '지원', '등', '국내', '재원', '동원', '강화', '선진국', '개발도상국', '공적', '개발원조', '규모', '국민', '총', '소득', '대비', '확대', '빈국', '공적', '개발원조', '국민', '총', '소득', '대비', '제공', '공약', '달성', '포함', '공적', '개발원조', '책무', '이행', '공여국', '빈국', '공적', '개발원조', '규모', '국민', '총', '소득', '대비', '최소', '제공', '목표', '설정', '것', '고려', '장려', '원천', '개도국', '추가', '금융', '재원', '동원', '경우', '부채', '조달', '부채', '탕감', '부채', '조정', '정책', '조율', '개발', '도상국', '장기', '부채', '상환', '능력', '을', '수', '지원', '채무', '빈곤국', '의', '채무', '부담', '완화', '외채', '문제', '대응', '빈국', '투자', '증진', '계획', '채택', '이행', '과학', '기술', '혁신', '남북', '남남', '삼각', '협력', '등', '지역', '국제', '협력', '접근', '강화', '현존', '메커니즘', '조정', '차원', '개선', '세계', '기술', '증진', '메커니즘', '등', '상호', '합의', '기초', '지식', '공유', '증대', '상호', '합의', '양허', '특혜', '조건', '등', '개도국', '조건', '환경기술', '개발', '이전', '보급', '확산', '촉진', '년', '빈국', '기술', '은행', '과학', '기술', '혁신', '역량', '강화', '메커니즘', '운용', '정보통신기술', '과', '구현', '기술', '활용', '강화', '남북', '남남', '삼각', '협력', '등', '지속', '가능', '발전', '목표', '이행', '수립', '개발도상국', '국가', '계획', '지원', '수', '효과', '선별', '목표', '지향', '역량', '강화', '이행', '국제', '사회', '지원', '강화', '도하', '개발', '어제', '협상', '타결', '등', '세계무역기구', '체제', '하', '보편', '규칙', '기반', '개방', '차별', '평등', '다자', '무역', '체제', '증진', '개도국', '수출', '증가', '년', '세계', '수출', '최', '빈', '개도국', '차지', '수출량', '배', '증가', '최', '빈', '개도국', '수입품', '적용', '특혜', '원산지', '규정', '투명', '시장', '접근', '촉진', '기여', '세계무역기구', '결정', '일치', '최', '빈', '개도국', '영구', '관세', '쿼터', '시장', '접근', '적시', '이행', '정책', '조정', '정책', '일', '관성', '등', '글로벌', '거시', '경제', '안정', '강화', '지속', '가능', '발전', '정책', '강화', '빈곤', '퇴치', '지속', '가능', '발전', '정책', '수립', '이행', '각국', '정책', '재량', '리더십', '존중', '국가', '개도국', '지속', '가능', '발전', '목표', '달성', '지원', '지식', '전문', '기술', '재원', '동원', '공유', '다', '주체', '파트너십', '보완', '지속', '가능', '발전', '글로벌', '파트너십', '강화', '파트너십', '경험', '재원', '조달', '전략', '바탕', '효과', '공공', '민관', '시민사회', '파트너십', '장려', '도모', '년', '빈국', '군소', '도서', '개도국', '포함', '개발도상국', '양질', '시의', '신뢰', '세분', '소득', '성별', '연령', '인종', '민족', '이주', '상태', '장애', '여부', '지리', '위치', '기타', '국', '맥락', '데이터', '가용성', '향상', '역량', '강화', '지원', '확대', '년', '국내', '총', '생산', '을', '보완', '지속', '가능', '발전', '이행', '정도', '측정', '방법', '개발', '기존', '이니셔티브', '기반', '발전', '개발도상국', '통계', '역량', '강화', '지원']

# %%
from collections import Counter
# 4. 단어 빈도 계산 함수 정의
def calculate_top_frequencies(text, top_n=10):
    """
    텍스트에서 단어 빈도를 계산하고 상위 top_n 단어를 반환.
    """
    words = text.split()  # 공백 기준으로 단어 분리
    word_counts = Counter(words)  # 단어 빈도 계산
    return word_counts.most_common(top_n)  # 상위 top_n 단어 반환

# 5. 각 파일별 상위 빈도 추출
top_frequencies_texts = {
    key: calculate_top_frequencies(content, top_n=10) for key, content in preprocessed_texts.items()
}

top_frequencies_categories = [
    calculate_top_frequencies(category, top_n=10) for category in preprocessed_categories
]

# 6. 결과 확인
print("2015년 데이터 상위 빈도 결과:\n", top_frequencies_texts["2015년 데이터"])
print("\n2022년 데이터 상위 빈도 결과:\n", top_frequencies_texts["2022년 데이터"])

print("\n카테고리 데이터 상위 빈도 결과:")
for i, top_frequencies in enumerate(top_frequencies_categories, start=1):
    print(f"문서 {i} 상위 빈도 결과: {top_frequencies}")
# Out:
# 2015년 데이터 상위 빈도 결과:
#  [('시간', 429), ('자원', 383), ('관리', 247), ('생활', 206), ('수', 197), ('사용', 129), ('목표', 119), ('계획', 115), ('것', 111), ('일', 111)]
#
# 2022년 데이터 상위 빈도 결과:
#  [('자원', 535), ('생활', 301), ('수', 183), ('사용', 179), ('환경', 161), ('순환', 97), ('등', 92), ('과정', 89), ('관리', 85), ('생산', 84)]
#
# 카테고리 데이터 상위 빈도 결과:
# 문서 1 상위 빈도 결과: [('빈곤', 9), ('년', 5), ('국가', 3), ('사회', 3), ('계층', 3), ('보장', 3), ('곳', 2), ('종식', 2), ('인구', 2), ('측면', 2)]
# 문서 2 상위 빈도 결과: [('농업', 6), ('년', 6), ('식량', 5), ('시장', 5), ('접근', 4), ('국제', 4), ('안전', 3), ('영양', 3), ('보장', 3), ('생산', 3)]
# 문서 3 상위 빈도 결과: [('년', 7), ('사망', 7), ('보건', 7), ('보장', 5), ('국가', 5), ('질병', 5), ('접근', 5), ('세계', 4), ('건강', 3), ('건의', 3)]
# 문서 4 상위 빈도 결과: [('교육', 14), ('년', 9), ('보장', 7), ('양질', 5), ('기술', 5), ('지속', 4), ('가능', 4), ('학습', 3), ('증진', 3), ('수', 3)]
# 문서 5 상위 빈도 결과: [('여성', 8), ('평등', 5), ('여아', 4), ('성', 3), ('권익', 3), ('신장', 3), ('증진', 3), ('대상', 2), ('형태', 2), ('착취', 2)]
# 문서 6 상위 빈도 결과: [('물', 8), ('년', 7), ('위생', 4), ('모두', 3), ('관리', 3), ('지속', 2), ('보장', 2), ('안전', 2), ('공평', 2), ('접근', 2)]
# 문서 7 상위 빈도 결과: [('에너지', 8), ('년', 5), ('기술', 4), ('개도국', 4), ('수', 3), ('현대', 3), ('접근', 3), ('모두', 2), ('적정', 2), ('가격', 2)]
# 문서 8 상위 빈도 결과: [('노동', 6), ('년', 6), ('생산', 5), ('고용', 5), ('포함', 5), ('지속', 4), ('일자리', 4), ('양질', 3), ('빈국', 3), ('산업', 3)]
# 문서 9 상위 빈도 결과: [('사회', 5), ('기반', 5), ('시설', 5), ('지속', 5), ('산업', 5), ('개도국', 5), ('접근', 4), ('년', 4), ('국가', 4), ('기술', 4)]
# 문서 10 상위 빈도 결과: [('정책', 7), ('개도국', 6), ('국가', 5), ('년', 3), ('경제', 3), ('강화', 3), ('이행', 3), ('불평등', 2), ('감소', 2), ('수준', 2)]
# 문서 11 상위 빈도 결과: [('년', 7), ('재난', 6), ('안전', 5), ('지속', 5), ('도시', 5), ('접근', 5), ('포용', 4), ('회복', 3), ('력', 3), ('환경', 3)]
# 문서 12 상위 빈도 결과: [('지속', 10), ('년', 5), ('영향', 5), ('소비', 4), ('생산', 4), ('발전', 4), ('양식', 3), ('개발도상국', 3), ('국가', 3), ('발생', 3)]
# 문서 13 상위 빈도 결과: [('기후', 7), ('변화', 5), ('국가', 3), ('영향', 2), ('관련', 2), ('강화', 2), ('계획', 2), ('완화', 2), ('역량', 2), ('이행', 2)]
# 문서 14 상위 빈도 결과: [('해양', 17), ('지속', 8), ('개도국', 7), ('자원', 6), ('년', 6), ('보전', 4), ('이용', 4), ('과학', 4), ('어업', 4), ('보조금', 4)]
# 문서 15 상위 빈도 결과: [('지속', 8), ('산림', 8), ('생태계', 7), ('년', 7), ('생물', 5), ('다양성', 5), ('보호', 4), ('복원', 4), ('이용', 4), ('관리', 4)]
# 문서 16 상위 빈도 결과: [('제도', 5), ('보장', 4), ('형태', 4), ('폭력', 4), ('강화', 4), ('포용', 3), ('증진', 3), ('모두', 3), ('감소', 3), ('국제', 3)]
# 문서 17 상위 빈도 결과: [('강화', 12), ('개도국', 9), ('이행', 8), ('발전', 8), ('지속', 7), ('가능', 7), ('지원', 7), ('등', 7), ('정책', 6), ('기술', 6)]

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# TfidfVectorizer가 이미 토큰화된 데이터를 처리할 수 있도록 analyzer를 직접 설정합니다.
vectorizer = TfidfVectorizer(analyzer=lambda x: x)
tfidf_matrix = vectorizer.fit_transform(tokenized_categories)
feature_names = vectorizer.get_feature_names_out()

# 각 기준서(문서)별 상위 10개 단어와 해당 TF-IDF 점수를 추출
top_words_per_category = []
for i in range(tfidf_matrix.shape[0]):
    # 각 문서의 TF-IDF 벡터를 1차원 배열로 추출
    row = tfidf_matrix.getrow(i).toarray().flatten()
    # TF-IDF 값이 큰 순서대로 인덱스를 정렬
    sorted_indices = np.argsort(row)[::-1]
    top10 = []
    for idx in sorted_indices:
        if row[idx] <= 0:  # TF-IDF 점수가 0 이하이면 중단
            break
        top10.append((feature_names[idx], row[idx]))
        if len(top10) == 10:
            break
    top_words_per_category.append(top10)
    print(f"문서 {i+1} 상위 10개 단어:", top10)
# Out:
# 문서 1 상위 10개 단어: [('빈곤', 0.5298302209081608), ('계층', 0.20717091691317266), ('측면', 0.19359671436967793), ('동등', 0.1690451976330317), ('년', 0.1600312947504845), ('곳', 0.15162561928857698), ('권리', 0.15162561928857698), ('인구', 0.13811394460878176), ('사회', 0.12765451120624463), ('종식', 0.109654524207476)]
# 문서 2 상위 10개 단어: [('농업', 0.39744221874735153), ('식량', 0.3312018489561263), ('시장', 0.20142760212635827), ('영양', 0.17351972794218973), ('기아', 0.13248073958245052), ('식물', 0.13248073958245052), ('가축', 0.13248073958245052), ('농산물', 0.13248073958245052), ('년', 0.13141378573851623), ('수출', 0.11567981862812647)]
# 문서 3 상위 10개 단어: [('보건', 0.3800824516702738), ('사망', 0.3800824516702738), ('질병', 0.271487465478767), ('건의', 0.1628924792872602), ('감염', 0.1628924792872602), ('생존', 0.1628924792872602), ('건', 0.1628924792872602), ('백신', 0.1628924792872602), ('의약품', 0.1628924792872602), ('출산', 0.1628924792872602)]
# 문서 4 상위 10개 단어: [('교육', 0.5914834228418708), ('양질', 0.19435873697536382), ('학습', 0.177662696639989), ('년', 0.17623186301314472), ('문화', 0.15513189758053153), ('실질', 0.15513189758053153), ('보장', 0.15329765102647047), ('가능', 0.14406590657343066), ('성', 0.13914604124467572), ('기술', 0.13016431131650838)]
# 문서 5 상위 10개 단어: [('여성', 0.3584980408304869), ('여아', 0.26510006074466513), ('평등', 0.25731876902197554), ('신장', 0.2538612916150297), ('권익', 0.2538612916150297), ('성', 0.19882504555849886), ('대상', 0.16924086107668646), ('회의', 0.16924086107668646), ('착취', 0.14777810099433103), ('재생산', 0.14777810099433103)]
# 문서 6 상위 10개 단어: [('물', 0.5349649800797611), ('위생', 0.34152362553313054), ('년', 0.1976176492040442), ('폐수', 0.17076181276656527), ('부족', 0.17076181276656527), ('처리', 0.17076181276656527), ('재활용', 0.14910616887938252), ('담수', 0.14910616887938252), ('재사용', 0.14910616887938252), ('모두', 0.12720407464049363)]
# 문서 7 상위 10개 단어: [('에너지', 0.7317454911360607), ('현대', 0.27440455917602274), ('청정에너지', 0.18293637278401517), ('재생', 0.18293637278401517), ('기술', 0.16083367479053606), ('개도국', 0.16083367479053606), ('년', 0.15121922233494536), ('신뢰', 0.13050874411730315), ('시설', 0.12007680745678581), ('기반', 0.11125673068467383)]
# 문서 8 상위 10개 단어: [('노동', 0.3564861088996123), ('고용', 0.2664594429306485), ('일자리', 0.21316755434451878), ('노동자', 0.20413043484150004), ('생산', 0.19270149445879692), ('산업', 0.17824305444980615), ('청년', 0.17824305444980615), ('동일', 0.13608695656100003), ('진흥', 0.13608695656100003), ('경제성장', 0.13608695656100003)]
# 문서 9 상위 10개 단어: [('산업', 0.3604597801948269), ('시설', 0.27096364591059796), ('기반', 0.25106038390687635), ('혁신', 0.19398931705582612), ('사회', 0.1814675116263689), ('개도국', 0.1814675116263689), ('증가', 0.17670252504988287), ('지속', 0.17113274706938522), ('산업화', 0.16512466508424237), ('기술', 0.1451740093010951)]
# 문서 10 상위 10개 단어: [('정책', 0.3060923756046912), ('개도국', 0.24706902045934168), ('철폐', 0.1873484537737333), ('송금', 0.1873484537737333), ('국가', 0.17320187413394755), ('비용', 0.16358932793636302), ('불평등', 0.16358932793636302), ('경제', 0.14882056231105228), ('규제', 0.14673195988210874), ('점진', 0.14673195988210874)]
# 문서 11 상위 10개 단어: [('도시', 0.3879169906767543), ('재난', 0.36458152176039027), ('안전', 0.21971887892389627), ('포용', 0.18873611847847427), ('년', 0.17956999294366122), ('지속', 0.16081255992987836), ('접근', 0.14345023605000748), ('환경', 0.1415520888588557), ('폐기물', 0.13548887865719603), ('주의', 0.13548887865719603)]
# 문서 12 상위 10개 단어: [('지속', 0.32141515764853024), ('소비', 0.2708008585412373), ('영향', 0.23576613551353737), ('양식', 0.23259825121982938), ('보조금', 0.1821717584488637), ('발생', 0.1821717584488637), ('생산', 0.17566035423719742), ('발전', 0.16423539176141463), ('식품', 0.1550655008132196), ('환경', 0.1414596813081224)]
# 문서 13 상위 10개 단어: [('기후', 0.5389253492344177), ('변화', 0.4226059766368209), ('완화', 0.16904239065472837), ('영향', 0.1312644885968611), ('국가', 0.11972221549963154), ('긴급', 0.10791728856080078), ('인적', 0.10791728856080078), ('녹색', 0.10791728856080078), ('배경', 0.10791728856080078), ('의미', 0.10791728856080078)]
# 문서 14 상위 10개 단어: [('해양', 0.7519431995642896), ('어업', 0.17692781166218577), ('보전', 0.15449020912670233), ('지속', 0.14669228211195476), ('자원', 0.14054290755893092), ('보조금', 0.1385704767769208), ('개도국', 0.13610719387330172), ('과학', 0.11613287424143738), ('이용', 0.11613287424143738), ('연안', 0.08846390583109288)]
# 문서 15 상위 10개 단어: [('산림', 0.4447398648832322), ('생태계', 0.27762185998773803), ('생물', 0.24271182300036823), ('훼손', 0.2223699324416161), ('다양성', 0.19830132856267002), ('지속', 0.18436871262062657), ('복원', 0.17416090364651343), ('방지', 0.16677744933121205), ('사막화', 0.16677744933121205), ('토지', 0.14596042960519198)]
# 문서 16 상위 10개 단어: [('제도', 0.40093440574884376), ('폭력', 0.320747524599075), ('단계', 0.24056064344930628), ('형태', 0.22340078168915142), ('포용', 0.16755058626686356), ('감소', 0.14589529638901963), ('기관', 0.14384774821639107), ('불법', 0.14384774821639107), ('구축', 0.14384774821639107), ('책임', 0.14384774821639107)]
# 문서 17 상위 10개 단어: [('파트너십', 0.23001648528038723), ('가능', 0.1958453339431028), ('발전', 0.19489491794624905), ('강화', 0.19299878550184352), ('부채', 0.1840131882243098), ('개도국', 0.18200293590795638), ('개발원조', 0.16067703355266635), ('이행', 0.15256682522508067), ('총', 0.14411976831641135), ('재원', 0.14411976831641135)]

# %%
# 정확히 '물'이라는 단어만 몇 개 나오는지 확인
count_water_2015 = preprocessed_texts["2015년 데이터"].split().count("시간")
count_water_2022 = preprocessed_texts["2022년 데이터"].split().count("물")

print("2015년 데이터에서 '물' 단어 개수:", count_water_2015)
print("2022년 데이터에서 '물' 단어 개수:", count_water_2022)
# Out:
# 2015년 데이터에서 '물' 단어 개수: 429
# 2022년 데이터에서 '물' 단어 개수: 50

# %%
counter_2015 = Counter(tokenized_texts["2015년 데이터"])
counter_2022 = Counter(tokenized_texts["2022년 데이터"])

print("기준서별 상위 10개 단어의 2015년, 2022년 등장 빈도:")
for idx, top_words in enumerate(top_words_per_category, start=1):
    print(f"\n기준서 {idx}:")
    for word, tfidf_score in top_words:
        count_2015 = counter_2015.get(word, 0)
        count_2022 = counter_2022.get(word, 0)
        print(f"  단어 '{word}': 2015년 = {count_2015}, 2022년 = {count_2022}")
# Out:
# 기준서별 상위 10개 단어의 2015년, 2022년 등장 빈도:
#
# 기준서 1:
#   단어 '빈곤': 2015년 = 0, 2022년 = 0
#   단어 '계층': 2015년 = 0, 2022년 = 0
#   단어 '측면': 2015년 = 0, 2022년 = 4
#   단어 '동등': 2015년 = 1, 2022년 = 0
#   단어 '년': 2015년 = 14, 2022년 = 8
#   단어 '곳': 2015년 = 1, 2022년 = 3
#   단어 '권리': 2015년 = 0, 2022년 = 2
#   단어 '인구': 2015년 = 0, 2022년 = 0
#   단어 '사회': 2015년 = 12, 2022년 = 19
#   단어 '종식': 2015년 = 0, 2022년 = 0
#
# 기준서 2:
#   단어 '농업': 2015년 = 0, 2022년 = 0
#   단어 '식량': 2015년 = 0, 2022년 = 3
#   단어 '시장': 2015년 = 1, 2022년 = 5
#   단어 '영양': 2015년 = 0, 2022년 = 0
#   단어 '기아': 2015년 = 0, 2022년 = 0
#   단어 '식물': 2015년 = 0, 2022년 = 0
#   단어 '가축': 2015년 = 0, 2022년 = 4
#   단어 '농산물': 2015년 = 0, 2022년 = 5
#   단어 '년': 2015년 = 14, 2022년 = 8
#   단어 '수출': 2015년 = 0, 2022년 = 0
#
# 기준서 3:
#   단어 '보건': 2015년 = 0, 2022년 = 0
#   단어 '사망': 2015년 = 0, 2022년 = 0
#   단어 '질병': 2015년 = 0, 2022년 = 2
#   단어 '건의': 2015년 = 0, 2022년 = 0
#   단어 '감염': 2015년 = 0, 2022년 = 0
#   단어 '생존': 2015년 = 0, 2022년 = 2
#   단어 '건': 2015년 = 1, 2022년 = 3
#   단어 '백신': 2015년 = 0, 2022년 = 0
#   단어 '의약품': 2015년 = 0, 2022년 = 1
#   단어 '출산': 2015년 = 0, 2022년 = 0
#
# 기준서 4:
#   단어 '교육': 2015년 = 0, 2022년 = 1
#   단어 '양질': 2015년 = 0, 2022년 = 1
#   단어 '학습': 2015년 = 17, 2022년 = 3
#   단어 '년': 2015년 = 14, 2022년 = 8
#   단어 '문화': 2015년 = 3, 2022년 = 5
#   단어 '실질': 2015년 = 0, 2022년 = 3
#   단어 '보장': 2015년 = 0, 2022년 = 0
#   단어 '가능': 2015년 = 0, 2022년 = 0
#   단어 '성': 2015년 = 4, 2022년 = 6
#   단어 '기술': 2015년 = 13, 2022년 = 13
#
# 기준서 5:
#   단어 '여성': 2015년 = 0, 2022년 = 0
#   단어 '여아': 2015년 = 0, 2022년 = 0
#   단어 '평등': 2015년 = 2, 2022년 = 0
#   단어 '신장': 2015년 = 0, 2022년 = 0
#   단어 '권익': 2015년 = 0, 2022년 = 0
#   단어 '성': 2015년 = 4, 2022년 = 6
#   단어 '대상': 2015년 = 2, 2022년 = 2
#   단어 '회의': 2015년 = 0, 2022년 = 0
#   단어 '착취': 2015년 = 0, 2022년 = 0
#   단어 '재생산': 2015년 = 0, 2022년 = 0
#
# 기준서 6:
#   단어 '물': 2015년 = 51, 2022년 = 50
#   단어 '위생': 2015년 = 1, 2022년 = 0
#   단어 '년': 2015년 = 14, 2022년 = 8
#   단어 '폐수': 2015년 = 0, 2022년 = 3
#   단어 '부족': 2015년 = 15, 2022년 = 8
#   단어 '처리': 2015년 = 3, 2022년 = 8
#   단어 '재활용': 2015년 = 2, 2022년 = 31
#   단어 '담수': 2015년 = 0, 2022년 = 0
#   단어 '재사용': 2015년 = 0, 2022년 = 17
#   단어 '모두': 2015년 = 1, 2022년 = 2
#
# 기준서 7:
#   단어 '에너지': 2015년 = 12, 2022년 = 55
#   단어 '현대': 2015년 = 0, 2022년 = 1
#   단어 '청정에너지': 2015년 = 0, 2022년 = 0
#   단어 '재생': 2015년 = 0, 2022년 = 8
#   단어 '기술': 2015년 = 13, 2022년 = 13
#   단어 '개도국': 2015년 = 0, 2022년 = 0
#   단어 '년': 2015년 = 14, 2022년 = 8
#   단어 '신뢰': 2015년 = 0, 2022년 = 0
#   단어 '시설': 2015년 = 1, 2022년 = 0
#   단어 '기반': 2015년 = 0, 2022년 = 0
#
# 기준서 8:
#   단어 '노동': 2015년 = 23, 2022년 = 1
#   단어 '고용': 2015년 = 0, 2022년 = 0
#   단어 '일자리': 2015년 = 0, 2022년 = 0
#   단어 '노동자': 2015년 = 0, 2022년 = 0
#   단어 '생산': 2015년 = 3, 2022년 = 84
#   단어 '산업': 2015년 = 0, 2022년 = 3
#   단어 '청년': 2015년 = 0, 2022년 = 0
#   단어 '동일': 2015년 = 0, 2022년 = 0
#   단어 '진흥': 2015년 = 0, 2022년 = 0
#   단어 '경제성장': 2015년 = 0, 2022년 = 0
#
# 기준서 9:
#   단어 '산업': 2015년 = 0, 2022년 = 3
#   단어 '시설': 2015년 = 1, 2022년 = 0
#   단어 '기반': 2015년 = 0, 2022년 = 0
#   단어 '혁신': 2015년 = 0, 2022년 = 1
#   단어 '사회': 2015년 = 12, 2022년 = 19
#   단어 '개도국': 2015년 = 0, 2022년 = 0
#   단어 '증가': 2015년 = 4, 2022년 = 19
#   단어 '지속': 2015년 = 0, 2022년 = 52
#   단어 '산업화': 2015년 = 0, 2022년 = 0
#   단어 '기술': 2015년 = 13, 2022년 = 13
#
# 기준서 10:
#   단어 '정책': 2015년 = 0, 2022년 = 2
#   단어 '개도국': 2015년 = 0, 2022년 = 0
#   단어 '철폐': 2015년 = 0, 2022년 = 0
#   단어 '송금': 2015년 = 0, 2022년 = 0
#   단어 '국가': 2015년 = 0, 2022년 = 4
#   단어 '비용': 2015년 = 0, 2022년 = 5
#   단어 '불평등': 2015년 = 0, 2022년 = 0
#   단어 '경제': 2015년 = 1, 2022년 = 8
#   단어 '규제': 2015년 = 0, 2022년 = 0
#   단어 '점진': 2015년 = 0, 2022년 = 0
#
# 기준서 11:
#   단어 '도시': 2015년 = 0, 2022년 = 1
#   단어 '재난': 2015년 = 0, 2022년 = 0
#   단어 '안전': 2015년 = 0, 2022년 = 2
#   단어 '포용': 2015년 = 0, 2022년 = 0
#   단어 '년': 2015년 = 14, 2022년 = 8
#   단어 '지속': 2015년 = 0, 2022년 = 52
#   단어 '접근': 2015년 = 2, 2022년 = 4
#   단어 '환경': 2015년 = 1, 2022년 = 161
#   단어 '폐기물': 2015년 = 0, 2022년 = 28
#   단어 '주의': 2015년 = 3, 2022년 = 0
#
# 기준서 12:
#   단어 '지속': 2015년 = 0, 2022년 = 52
#   단어 '소비': 2015년 = 2, 2022년 = 59
#   단어 '영향': 2015년 = 4, 2022년 = 42
#   단어 '양식': 2015년 = 0, 2022년 = 0
#   단어 '보조금': 2015년 = 0, 2022년 = 0
#   단어 '발생': 2015년 = 3, 2022년 = 71
#   단어 '생산': 2015년 = 3, 2022년 = 84
#   단어 '발전': 2015년 = 14, 2022년 = 4
#   단어 '식품': 2015년 = 1, 2022년 = 23
#   단어 '환경': 2015년 = 1, 2022년 = 161
#
# 기준서 13:
#   단어 '기후': 2015년 = 0, 2022년 = 49
#   단어 '변화': 2015년 = 0, 2022년 = 12
#   단어 '완화': 2015년 = 0, 2022년 = 0
#   단어 '영향': 2015년 = 4, 2022년 = 42
#   단어 '국가': 2015년 = 0, 2022년 = 4
#   단어 '긴급': 2015년 = 20, 2022년 = 0
#   단어 '인적': 2015년 = 64, 2022년 = 33
#   단어 '녹색': 2015년 = 0, 2022년 = 1
#   단어 '배경': 2015년 = 0, 2022년 = 4
#   단어 '의미': 2015년 = 8, 2022년 = 10
#
# 기준서 14:
#   단어 '해양': 2015년 = 0, 2022년 = 1
#   단어 '어업': 2015년 = 0, 2022년 = 0
#   단어 '보전': 2015년 = 0, 2022년 = 2
#   단어 '지속': 2015년 = 0, 2022년 = 52
#   단어 '자원': 2015년 = 383, 2022년 = 535
#   단어 '보조금': 2015년 = 0, 2022년 = 0
#   단어 '개도국': 2015년 = 0, 2022년 = 0
#   단어 '과학': 2015년 = 3, 2022년 = 0
#   단어 '이용': 2015년 = 9, 2022년 = 32
#   단어 '연안': 2015년 = 0, 2022년 = 0
#
# 기준서 15:
#   단어 '산림': 2015년 = 0, 2022년 = 2
#   단어 '생태계': 2015년 = 0, 2022년 = 9
#   단어 '생물': 2015년 = 0, 2022년 = 6
#   단어 '훼손': 2015년 = 0, 2022년 = 4
#   단어 '다양성': 2015년 = 0, 2022년 = 5
#   단어 '지속': 2015년 = 0, 2022년 = 52
#   단어 '복원': 2015년 = 0, 2022년 = 0
#   단어 '방지': 2015년 = 0, 2022년 = 1
#   단어 '사막화': 2015년 = 0, 2022년 = 0
#   단어 '토지': 2015년 = 0, 2022년 = 2
#
# 기준서 16:
#   단어 '제도': 2015년 = 0, 2022년 = 1
#   단어 '폭력': 2015년 = 0, 2022년 = 0
#   단어 '단계': 2015년 = 11, 2022년 = 19
#   단어 '형태': 2015년 = 10, 2022년 = 8
#   단어 '포용': 2015년 = 0, 2022년 = 0
#   단어 '감소': 2015년 = 0, 2022년 = 6
#   단어 '기관': 2015년 = 0, 2022년 = 2
#   단어 '불법': 2015년 = 0, 2022년 = 0
#   단어 '구축': 2015년 = 0, 2022년 = 0
#   단어 '책임': 2015년 = 1, 2022년 = 1
#
# 기준서 17:
#   단어 '파트너십': 2015년 = 0, 2022년 = 0
#   단어 '가능': 2015년 = 0, 2022년 = 0
#   단어 '발전': 2015년 = 14, 2022년 = 4
#   단어 '강화': 2015년 = 0, 2022년 = 0
#   단어 '부채': 2015년 = 0, 2022년 = 0
#   단어 '개도국': 2015년 = 0, 2022년 = 0
#   단어 '개발원조': 2015년 = 0, 2022년 = 0
#   단어 '이행': 2015년 = 0, 2022년 = 0
#   단어 '총': 2015년 = 0, 2022년 = 0
#   단어 '재원': 2015년 = 0, 2022년 = 0

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from tqdm import tqdm

# ----------------------------------------
# 전제: text_data, categories, stopwords, preprocess_nouns,
#       top_words_per_category가 이미 정의되어 있음.
# ----------------------------------------

# ====================================================
# Step 1. 연도별 텍스트 전처리 및 토큰 카운터 생성
# ====================================================
year_token_counts = {}  # {year_label: Counter(tokens)}

for year_label, year_text in tqdm(text_data.items(), desc="연도별 전처리", unit="년"):
    # preprocess_nouns 함수는 한글 명사만 남기도록 전처리하는 함수입니다.
    preprocessed_text = preprocess_nouns(year_text, stopwords=stopwords)
    # 공백 기준 토큰화
    tokens = preprocessed_text.split()
    token_counter = collections.Counter(tokens)
    year_token_counts[year_label] = token_counter
    print(f"{year_label} - Total tokens: {len(tokens)}, Unique tokens: {len(token_counter)}")

# ====================================================
# Step 2. 각 연도별 기준서 점수 및 단어별 등장 횟수 계산
# ====================================================
results = []               # 각 기준서별 전체 점수를 저장할 리스트
detailed_word_counts = []  # 단어별 등장 횟수 및 기여 점수 상세 정보를 저장할 리스트

for year_label, token_counter in tqdm(year_token_counts.items(), desc="연도별 처리", unit="년"):
    print(f"\n===== {year_label} =====")
    for cat_idx, top_words in tqdm(enumerate(top_words_per_category, start=1),
                                   total=len(top_words_per_category),
                                   desc="기준서 처리", unit="문서", leave=False):
        cat_score = 0.0
        print(f"\n[기준서 {cat_idx}]")
        for word, weight in top_words:
            # 미리 계산된 token_counter에서 단어의 빈도 조회 (없으면 0)
            count = token_counter.get(word, 0)
            contribution = count * weight
            cat_score += contribution
            print(f"  단어 '{word}': Count = {count}, TF-IDF = {weight:.3f}, Contribution = {contribution:.3f}")
            detailed_word_counts.append({
                "Year": year_label,
                "Category": f"기준서 {cat_idx}",
                "Word": word,
                "TF-IDF": weight,
                "Count": count,
                "Contribution": contribution
            })
        print(f">> 기준서 {cat_idx} Final Score: {cat_score:.3f}")
        results.append({
            "Year": year_label,
            "Category": f"기준서 {cat_idx}",
            "Score": cat_score
        })

# ====================================================
# Step 3. 결과 DataFrame 생성 및 시각화
# ====================================================
# 전체 기준서 점수 DataFrame
df_results = pd.DataFrame(results)
print("\n===== Computed Category Scores =====")
print(df_results)

# 단어별 상세 등장 횟수 및 기여 점수 DataFrame
df_detailed = pd.DataFrame(detailed_word_counts)
print("\n===== Detailed Word Counts and Contributions =====")
print(df_detailed)

# 바 차트를 이용한 연도별, 기준서별 전체 점수 비교
plt.figure(figsize=(10, 6))
sns.barplot(x="Category", y="Score", hue="Year", data=df_results)
plt.xticks(rotation=45)
plt.title("연도별 기준서 점수 비교")
plt.tight_layout()
plt.show()

# 각 연도별 기준서 점수 요약 통계 (평균, 최소, 최대, 중앙값)
summary_stats = df_results.groupby("Year")["Score"].agg(["mean", "min", "max", "median"]).reset_index()
print("\n===== Summary Statistics by Year =====")
print(summary_stats)
# Out:
# 연도별 전처리:  50%|█████     | 1/2 [00:10<00:10, 10.56s/년]
# 2015년 데이터 - Total tokens: 6780, Unique tokens: 1020
# 연도별 전처리: 100%|██████████| 2/2 [00:22<00:00, 11.10s/년]
# 2022년 데이터 - Total tokens: 7649, Unique tokens: 1307
# 연도별 처리:   0%|          | 0/2 [00:00<?, ?년/s]
# ===== 2015년 데이터 =====
# 기준서 처리:   0%|          | 0/17 [00:00<?, ?문서/s]
# [기준서 1]
#   단어 '빈곤': Count = 0, TF-IDF = 0.530, Contribution = 0.000
#   단어 '계층': Count = 0, TF-IDF = 0.207, Contribution = 0.000
#   단어 '측면': Count = 0, TF-IDF = 0.194, Contribution = 0.000
#   단어 '동등': Count = 1, TF-IDF = 0.169, Contribution = 0.169
#   단어 '년': Count = 14, TF-IDF = 0.160, Contribution = 2.240
#   단어 '곳': Count = 1, TF-IDF = 0.152, Contribution = 0.152
#   단어 '권리': Count = 0, TF-IDF = 0.152, Contribution = 0.000
#   단어 '인구': Count = 0, TF-IDF = 0.138, Contribution = 0.000
#   단어 '사회': Count = 12, TF-IDF = 0.128, Contribution = 1.532
#   단어 '종식': Count = 0, TF-IDF = 0.110, Contribution = 0.000
# >> 기준서 1 Final Score: 4.093
#
# [기준서 2]
#   단어 '농업': Count = 0, TF-IDF = 0.397, Contribution = 0.000
#   단어 '식량': Count = 0, TF-IDF = 0.331, Contribution = 0.000
#   단어 '시장': Count = 1, TF-IDF = 0.201, Contribution = 0.201
#   단어 '영양': Count = 0, TF-IDF = 0.174, Contribution = 0.000
#   단어 '기아': Count = 0, TF-IDF = 0.132, Contribution = 0.000
#   단어 '식물': Count = 0, TF-IDF = 0.132, Contribution = 0.000
#   단어 '가축': Count = 0, TF-IDF = 0.132, Contribution = 0.000
#   단어 '농산물': Count = 0, TF-IDF = 0.132, Contribution = 0.000
#   단어 '년': Count = 14, TF-IDF = 0.131, Contribution = 1.840
#   단어 '수출': Count = 0, TF-IDF = 0.116, Contribution = 0.000
# >> 기준서 2 Final Score: 2.041
#
# [기준서 3]
#   단어 '보건': Count = 0, TF-IDF = 0.380, Contribution = 0.000
#   단어 '사망': Count = 0, TF-IDF = 0.380, Contribution = 0.000
#   단어 '질병': Count = 0, TF-IDF = 0.271, Contribution = 0.000
#   단어 '건의': Count = 0, TF-IDF = 0.163, Contribution = 0.000
#   단어 '감염': Count = 0, TF-IDF = 0.163, Contribution = 0.000
#   단어 '생존': Count = 0, TF-IDF = 0.163, Contribution = 0.000
#   단어 '건': Count = 1, TF-IDF = 0.163, Contribution = 0.163
#   단어 '백신': Count = 0, TF-IDF = 0.163, Contribution = 0.000
#   단어 '의약품': Count = 0, TF-IDF = 0.163, Contribution = 0.000
#   단어 '출산': Count = 0, TF-IDF = 0.163, Contribution = 0.000
# >> 기준서 3 Final Score: 0.163
#
# [기준서 4]
#   단어 '교육': Count = 0, TF-IDF = 0.591, Contribution = 0.000
#   단어 '양질': Count = 0, TF-IDF = 0.194, Contribution = 0.000
#   단어 '학습': Count = 17, TF-IDF = 0.178, Contribution = 3.020
#   단어 '년': Count = 14, TF-IDF = 0.176, Contribution = 2.467
#   단어 '문화': Count = 3, TF-IDF = 0.155, Contribution = 0.465
#   단어 '실질': Count = 0, TF-IDF = 0.155, Contribution = 0.000
#   단어 '보장': Count = 0, TF-IDF = 0.153, Contribution = 0.000
#   단어 '가능': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '성': Count = 4, TF-IDF = 0.139, Contribution = 0.557
#   단어 '기술': Count = 13, TF-IDF = 0.130, Contribution = 1.692
# >> 기준서 4 Final Score: 8.202
#
# [기준서 5]
#   단어 '여성': Count = 0, TF-IDF = 0.358, Contribution = 0.000
#   단어 '여아': Count = 0, TF-IDF = 0.265, Contribution = 0.000
#   단어 '평등': Count = 2, TF-IDF = 0.257, Contribution = 0.515
#   단어 '신장': Count = 0, TF-IDF = 0.254, Contribution = 0.000
#   단어 '권익': Count = 0, TF-IDF = 0.254, Contribution = 0.000
#   단어 '성': Count = 4, TF-IDF = 0.199, Contribution = 0.795
#   단어 '대상': Count = 2, TF-IDF = 0.169, Contribution = 0.338
#   단어 '회의': Count = 0, TF-IDF = 0.169, Contribution = 0.000
#   단어 '착취': Count = 0, TF-IDF = 0.148, Contribution = 0.000
#   단어 '재생산': Count = 0, TF-IDF = 0.148, Contribution = 0.000
# >> 기준서 5 Final Score: 1.648
#
# [기준서 6]
#   단어 '물': Count = 51, TF-IDF = 0.535, Contribution = 27.283
#   단어 '위생': Count = 1, TF-IDF = 0.342, Contribution = 0.342
#   단어 '년': Count = 14, TF-IDF = 0.198, Contribution = 2.767
#   단어 '폐수': Count = 0, TF-IDF = 0.171, Contribution = 0.000
#   단어 '부족': Count = 15, TF-IDF = 0.171, Contribution = 2.561
#   단어 '처리': Count = 3, TF-IDF = 0.171, Contribution = 0.512
#   단어 '재활용': Count = 2, TF-IDF = 0.149, Contribution = 0.298
#   단어 '담수': Count = 0, TF-IDF = 0.149, Contribution = 0.000
#   단어 '재사용': Count = 0, TF-IDF = 0.149, Contribution = 0.000
#   단어 '모두': Count = 1, TF-IDF = 0.127, Contribution = 0.127
# >> 기준서 6 Final Score: 33.891
#
# [기준서 7]
#   단어 '에너지': Count = 12, TF-IDF = 0.732, Contribution = 8.781
#   단어 '현대': Count = 0, TF-IDF = 0.274, Contribution = 0.000
#   단어 '청정에너지': Count = 0, TF-IDF = 0.183, Contribution = 0.000
#   단어 '재생': Count = 0, TF-IDF = 0.183, Contribution = 0.000
#   단어 '기술': Count = 13, TF-IDF = 0.161, Contribution = 2.091
#   단어 '개도국': Count = 0, TF-IDF = 0.161, Contribution = 0.000
#   단어 '년': Count = 14, TF-IDF = 0.151, Contribution = 2.117
#   단어 '신뢰': Count = 0, TF-IDF = 0.131, Contribution = 0.000
#   단어 '시설': Count = 1, TF-IDF = 0.120, Contribution = 0.120
#   단어 '기반': Count = 0, TF-IDF = 0.111, Contribution = 0.000
# >> 기준서 7 Final Score: 13.109
#
# [기준서 8]
#   단어 '노동': Count = 23, TF-IDF = 0.356, Contribution = 8.199
#   단어 '고용': Count = 0, TF-IDF = 0.266, Contribution = 0.000
#   단어 '일자리': Count = 0, TF-IDF = 0.213, Contribution = 0.000
#   단어 '노동자': Count = 0, TF-IDF = 0.204, Contribution = 0.000
#   단어 '생산': Count = 3, TF-IDF = 0.193, Contribution = 0.578
#   단어 '산업': Count = 0, TF-IDF = 0.178, Contribution = 0.000
#   단어 '청년': Count = 0, TF-IDF = 0.178, Contribution = 0.000
#   단어 '동일': Count = 0, TF-IDF = 0.136, Contribution = 0.000
#   단어 '진흥': Count = 0, TF-IDF = 0.136, Contribution = 0.000
#   단어 '경제성장': Count = 0, TF-IDF = 0.136, Contribution = 0.000
# >> 기준서 8 Final Score: 8.777
#
# [기준서 9]
#   단어 '산업': Count = 0, TF-IDF = 0.360, Contribution = 0.000
#   단어 '시설': Count = 1, TF-IDF = 0.271, Contribution = 0.271
#   단어 '기반': Count = 0, TF-IDF = 0.251, Contribution = 0.000
#   단어 '혁신': Count = 0, TF-IDF = 0.194, Contribution = 0.000
#   단어 '사회': Count = 12, TF-IDF = 0.181, Contribution = 2.178
#   단어 '개도국': Count = 0, TF-IDF = 0.181, Contribution = 0.000
#   단어 '증가': Count = 4, TF-IDF = 0.177, Contribution = 0.707
#   단어 '지속': Count = 0, TF-IDF = 0.171, Contribution = 0.000
#   단어 '산업화': Count = 0, TF-IDF = 0.165, Contribution = 0.000
#   단어 '기술': Count = 13, TF-IDF = 0.145, Contribution = 1.887
# >> 기준서 9 Final Score: 5.043
#
# [기준서 10]
#   단어 '정책': Count = 0, TF-IDF = 0.306, Contribution = 0.000
#   단어 '개도국': Count = 0, TF-IDF = 0.247, Contribution = 0.000
#   단어 '철폐': Count = 0, TF-IDF = 0.187, Contribution = 0.000
#   단어 '송금': Count = 0, TF-IDF = 0.187, Contribution = 0.000
#   단어 '국가': Count = 0, TF-IDF = 0.173, Contribution = 0.000
#   단어 '비용': Count = 0, TF-IDF = 0.164, Contribution = 0.000
#   단어 '불평등': Count = 0, TF-IDF = 0.164, Contribution = 0.000
#   단어 '경제': Count = 1, TF-IDF = 0.149, Contribution = 0.149
#   단어 '규제': Count = 0, TF-IDF = 0.147, Contribution = 0.000
#   단어 '점진': Count = 0, TF-IDF = 0.147, Contribution = 0.000
# >> 기준서 10 Final Score: 0.149
#
# [기준서 11]
#   단어 '도시': Count = 0, TF-IDF = 0.388, Contribution = 0.000
#   단어 '재난': Count = 0, TF-IDF = 0.365, Contribution = 0.000
#   단어 '안전': Count = 0, TF-IDF = 0.220, Contribution = 0.000
#   단어 '포용': Count = 0, TF-IDF = 0.189, Contribution = 0.000
#   단어 '년': Count = 14, TF-IDF = 0.180, Contribution = 2.514
#   단어 '지속': Count = 0, TF-IDF = 0.161, Contribution = 0.000
#   단어 '접근': Count = 2, TF-IDF = 0.143, Contribution = 0.287
#   단어 '환경': Count = 1, TF-IDF = 0.142, Contribution = 0.142
#   단어 '폐기물': Count = 0, TF-IDF = 0.135, Contribution = 0.000
#   단어 '주의': Count = 3, TF-IDF = 0.135, Contribution = 0.406
# >> 기준서 11 Final Score: 3.349
#
# [기준서 12]
#   단어 '지속': Count = 0, TF-IDF = 0.321, Contribution = 0.000
#   단어 '소비': Count = 2, TF-IDF = 0.271, Contribution = 0.542
#   단어 '영향': Count = 4, TF-IDF = 0.236, Contribution = 0.943
#   단어 '양식': Count = 0, TF-IDF = 0.233, Contribution = 0.000
#   단어 '보조금': Count = 0, TF-IDF = 0.182, Contribution = 0.000
#   단어 '발생': Count = 3, TF-IDF = 0.182, Contribution = 0.547
#   단어 '생산': Count = 3, TF-IDF = 0.176, Contribution = 0.527
#   단어 '발전': Count = 14, TF-IDF = 0.164, Contribution = 2.299
#   단어 '식품': Count = 1, TF-IDF = 0.155, Contribution = 0.155
#   단어 '환경': Count = 1, TF-IDF = 0.141, Contribution = 0.141
# >> 기준서 12 Final Score: 5.154
#
# [기준서 13]
#   단어 '기후': Count = 0, TF-IDF = 0.539, Contribution = 0.000
#   단어 '변화': Count = 0, TF-IDF = 0.423, Contribution = 0.000
#   단어 '완화': Count = 0, TF-IDF = 0.169, Contribution = 0.000
#   단어 '영향': Count = 4, TF-IDF = 0.131, Contribution = 0.525
#   단어 '국가': Count = 0, TF-IDF = 0.120, Contribution = 0.000
#   단어 '긴급': Count = 20, TF-IDF = 0.108, Contribution = 2.158
#   단어 '인적': Count = 64, TF-IDF = 0.108, Contribution = 6.907
#   단어 '녹색': Count = 0, TF-IDF = 0.108, Contribution = 0.000
#   단어 '배경': Count = 0, TF-IDF = 0.108, Contribution = 0.000
#   단어 '의미': Count = 8, TF-IDF = 0.108, Contribution = 0.863
# >> 기준서 13 Final Score: 10.453
#
# [기준서 14]
#   단어 '해양': Count = 0, TF-IDF = 0.752, Contribution = 0.000
#   단어 '어업': Count = 0, TF-IDF = 0.177, Contribution = 0.000
#   단어 '보전': Count = 0, TF-IDF = 0.154, Contribution = 0.000
#   단어 '지속': Count = 0, TF-IDF = 0.147, Contribution = 0.000
#   단어 '자원': Count = 383, TF-IDF = 0.141, Contribution = 53.828
#   단어 '보조금': Count = 0, TF-IDF = 0.139, Contribution = 0.000
#   단어 '개도국': Count = 0, TF-IDF = 0.136, Contribution = 0.000
#   단어 '과학': Count = 3, TF-IDF = 0.116, Contribution = 0.348
#   단어 '이용': Count = 9, TF-IDF = 0.116, Contribution = 1.045
#   단어 '연안': Count = 0, TF-IDF = 0.088, Contribution = 0.000
# >> 기준서 14 Final Score: 55.222
#
# [기준서 15]
#   단어 '산림': Count = 0, TF-IDF = 0.445, Contribution = 0.000
#   단어 '생태계': Count = 0, TF-IDF = 0.278, Contribution = 0.000
#   단어 '생물': Count = 0, TF-IDF = 0.243, Contribution = 0.000
#   단어 '훼손': Count = 0, TF-IDF = 0.222, Contribution = 0.000
#   단어 '다양성': Count = 0, TF-IDF = 0.198, Contribution = 0.000
#   단어 '지속': Count = 0, TF-IDF = 0.184, Contribution = 0.000
#   단어 '복원': Count = 0, TF-IDF = 0.174, Contribution = 0.000
#   단어 '방지': Count = 0, TF-IDF = 0.167, Contribution = 0.000
#   단어 '사막화': Count = 0, TF-IDF = 0.167, Contribution = 0.000
#   단어 '토지': Count = 0, TF-IDF = 0.146, Contribution = 0.000
# >> 기준서 15 Final Score: 0.000
#
# [기준서 16]
#   단어 '제도': Count = 0, TF-IDF = 0.401, Contribution = 0.000
#   단어 '폭력': Count = 0, TF-IDF = 0.321, Contribution = 0.000
#   단어 '단계': Count = 11, TF-IDF = 0.241, Contribution = 2.646
#   단어 '형태': Count = 10, TF-IDF = 0.223, Contribution = 2.234
#   단어 '포용': Count = 0, TF-IDF = 0.168, Contribution = 0.000
#   단어 '감소': Count = 0, TF-IDF = 0.146, Contribution = 0.000
#   단어 '기관': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '불법': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '구축': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '책임': Count = 1, TF-IDF = 0.144, Contribution = 0.144
# >> 기준서 16 Final Score: 5.024
#
# [기준서 17]
#   단어 '파트너십': Count = 0, TF-IDF = 0.230, Contribution = 0.000
#   단어 '가능': Count = 0, TF-IDF = 0.196, Contribution = 0.000
#   단어 '발전': Count = 14, TF-IDF = 0.195, Contribution = 2.729
#   단어 '강화': Count = 0, TF-IDF = 0.193, Contribution = 0.000
#   단어 '부채': Count = 0, TF-IDF = 0.184, Contribution = 0.000
#   단어 '개도국': Count = 0, TF-IDF = 0.182, Contribution = 0.000
#   단어 '개발원조': Count = 0, TF-IDF = 0.161, Contribution = 0.000
#   단어 '이행': Count = 0, TF-IDF = 0.153, Contribution = 0.000
#   단어 '총': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '재원': Count = 0, TF-IDF = 0.144, Contribution = 0.000
# >> 기준서 17 Final Score: 2.729
#
# ===== 2022년 데이터 =====
# 기준서 처리:   0%|          | 0/17 [00:00<?, ?문서/s]
# 연도별 처리: 100%|██████████| 2/2 [00:00<00:00, 117.19년/s]
# [기준서 1]
#   단어 '빈곤': Count = 0, TF-IDF = 0.530, Contribution = 0.000
#   단어 '계층': Count = 0, TF-IDF = 0.207, Contribution = 0.000
#   단어 '측면': Count = 4, TF-IDF = 0.194, Contribution = 0.774
#   단어 '동등': Count = 0, TF-IDF = 0.169, Contribution = 0.000
#   단어 '년': Count = 8, TF-IDF = 0.160, Contribution = 1.280
#   단어 '곳': Count = 3, TF-IDF = 0.152, Contribution = 0.455
#   단어 '권리': Count = 2, TF-IDF = 0.152, Contribution = 0.303
#   단어 '인구': Count = 0, TF-IDF = 0.138, Contribution = 0.000
#   단어 '사회': Count = 19, TF-IDF = 0.128, Contribution = 2.425
#   단어 '종식': Count = 0, TF-IDF = 0.110, Contribution = 0.000
# >> 기준서 1 Final Score: 5.238
#
# [기준서 2]
#   단어 '농업': Count = 0, TF-IDF = 0.397, Contribution = 0.000
#   단어 '식량': Count = 3, TF-IDF = 0.331, Contribution = 0.994
#   단어 '시장': Count = 5, TF-IDF = 0.201, Contribution = 1.007
#   단어 '영양': Count = 0, TF-IDF = 0.174, Contribution = 0.000
#   단어 '기아': Count = 0, TF-IDF = 0.132, Contribution = 0.000
#   단어 '식물': Count = 0, TF-IDF = 0.132, Contribution = 0.000
#   단어 '가축': Count = 4, TF-IDF = 0.132, Contribution = 0.530
#   단어 '농산물': Count = 5, TF-IDF = 0.132, Contribution = 0.662
#   단어 '년': Count = 8, TF-IDF = 0.131, Contribution = 1.051
#   단어 '수출': Count = 0, TF-IDF = 0.116, Contribution = 0.000
# >> 기준서 2 Final Score: 4.244
#
# [기준서 3]
#   단어 '보건': Count = 0, TF-IDF = 0.380, Contribution = 0.000
#   단어 '사망': Count = 0, TF-IDF = 0.380, Contribution = 0.000
#   단어 '질병': Count = 2, TF-IDF = 0.271, Contribution = 0.543
#   단어 '건의': Count = 0, TF-IDF = 0.163, Contribution = 0.000
#   단어 '감염': Count = 0, TF-IDF = 0.163, Contribution = 0.000
#   단어 '생존': Count = 2, TF-IDF = 0.163, Contribution = 0.326
#   단어 '건': Count = 3, TF-IDF = 0.163, Contribution = 0.489
#   단어 '백신': Count = 0, TF-IDF = 0.163, Contribution = 0.000
#   단어 '의약품': Count = 1, TF-IDF = 0.163, Contribution = 0.163
#   단어 '출산': Count = 0, TF-IDF = 0.163, Contribution = 0.000
# >> 기준서 3 Final Score: 1.520
#
# [기준서 4]
#   단어 '교육': Count = 1, TF-IDF = 0.591, Contribution = 0.591
#   단어 '양질': Count = 1, TF-IDF = 0.194, Contribution = 0.194
#   단어 '학습': Count = 3, TF-IDF = 0.178, Contribution = 0.533
#   단어 '년': Count = 8, TF-IDF = 0.176, Contribution = 1.410
#   단어 '문화': Count = 5, TF-IDF = 0.155, Contribution = 0.776
#   단어 '실질': Count = 3, TF-IDF = 0.155, Contribution = 0.465
#   단어 '보장': Count = 0, TF-IDF = 0.153, Contribution = 0.000
#   단어 '가능': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '성': Count = 6, TF-IDF = 0.139, Contribution = 0.835
#   단어 '기술': Count = 13, TF-IDF = 0.130, Contribution = 1.692
# >> 기준서 4 Final Score: 6.497
#
# [기준서 5]
#   단어 '여성': Count = 0, TF-IDF = 0.358, Contribution = 0.000
#   단어 '여아': Count = 0, TF-IDF = 0.265, Contribution = 0.000
#   단어 '평등': Count = 0, TF-IDF = 0.257, Contribution = 0.000
#   단어 '신장': Count = 0, TF-IDF = 0.254, Contribution = 0.000
#   단어 '권익': Count = 0, TF-IDF = 0.254, Contribution = 0.000
#   단어 '성': Count = 6, TF-IDF = 0.199, Contribution = 1.193
#   단어 '대상': Count = 2, TF-IDF = 0.169, Contribution = 0.338
#   단어 '회의': Count = 0, TF-IDF = 0.169, Contribution = 0.000
#   단어 '착취': Count = 0, TF-IDF = 0.148, Contribution = 0.000
#   단어 '재생산': Count = 0, TF-IDF = 0.148, Contribution = 0.000
# >> 기준서 5 Final Score: 1.531
#
# [기준서 6]
#   단어 '물': Count = 50, TF-IDF = 0.535, Contribution = 26.748
#   단어 '위생': Count = 0, TF-IDF = 0.342, Contribution = 0.000
#   단어 '년': Count = 8, TF-IDF = 0.198, Contribution = 1.581
#   단어 '폐수': Count = 3, TF-IDF = 0.171, Contribution = 0.512
#   단어 '부족': Count = 8, TF-IDF = 0.171, Contribution = 1.366
#   단어 '처리': Count = 8, TF-IDF = 0.171, Contribution = 1.366
#   단어 '재활용': Count = 31, TF-IDF = 0.149, Contribution = 4.622
#   단어 '담수': Count = 0, TF-IDF = 0.149, Contribution = 0.000
#   단어 '재사용': Count = 17, TF-IDF = 0.149, Contribution = 2.535
#   단어 '모두': Count = 2, TF-IDF = 0.127, Contribution = 0.254
# >> 기준서 6 Final Score: 38.985
#
# [기준서 7]
#   단어 '에너지': Count = 55, TF-IDF = 0.732, Contribution = 40.246
#   단어 '현대': Count = 1, TF-IDF = 0.274, Contribution = 0.274
#   단어 '청정에너지': Count = 0, TF-IDF = 0.183, Contribution = 0.000
#   단어 '재생': Count = 8, TF-IDF = 0.183, Contribution = 1.463
#   단어 '기술': Count = 13, TF-IDF = 0.161, Contribution = 2.091
#   단어 '개도국': Count = 0, TF-IDF = 0.161, Contribution = 0.000
#   단어 '년': Count = 8, TF-IDF = 0.151, Contribution = 1.210
#   단어 '신뢰': Count = 0, TF-IDF = 0.131, Contribution = 0.000
#   단어 '시설': Count = 0, TF-IDF = 0.120, Contribution = 0.000
#   단어 '기반': Count = 0, TF-IDF = 0.111, Contribution = 0.000
# >> 기준서 7 Final Score: 45.284
#
# [기준서 8]
#   단어 '노동': Count = 1, TF-IDF = 0.356, Contribution = 0.356
#   단어 '고용': Count = 0, TF-IDF = 0.266, Contribution = 0.000
#   단어 '일자리': Count = 0, TF-IDF = 0.213, Contribution = 0.000
#   단어 '노동자': Count = 0, TF-IDF = 0.204, Contribution = 0.000
#   단어 '생산': Count = 84, TF-IDF = 0.193, Contribution = 16.187
#   단어 '산업': Count = 3, TF-IDF = 0.178, Contribution = 0.535
#   단어 '청년': Count = 0, TF-IDF = 0.178, Contribution = 0.000
#   단어 '동일': Count = 0, TF-IDF = 0.136, Contribution = 0.000
#   단어 '진흥': Count = 0, TF-IDF = 0.136, Contribution = 0.000
#   단어 '경제성장': Count = 0, TF-IDF = 0.136, Contribution = 0.000
# >> 기준서 8 Final Score: 17.078
#
# [기준서 9]
#   단어 '산업': Count = 3, TF-IDF = 0.360, Contribution = 1.081
#   단어 '시설': Count = 0, TF-IDF = 0.271, Contribution = 0.000
#   단어 '기반': Count = 0, TF-IDF = 0.251, Contribution = 0.000
#   단어 '혁신': Count = 1, TF-IDF = 0.194, Contribution = 0.194
#   단어 '사회': Count = 19, TF-IDF = 0.181, Contribution = 3.448
#   단어 '개도국': Count = 0, TF-IDF = 0.181, Contribution = 0.000
#   단어 '증가': Count = 19, TF-IDF = 0.177, Contribution = 3.357
#   단어 '지속': Count = 52, TF-IDF = 0.171, Contribution = 8.899
#   단어 '산업화': Count = 0, TF-IDF = 0.165, Contribution = 0.000
#   단어 '기술': Count = 13, TF-IDF = 0.145, Contribution = 1.887
# >> 기준서 9 Final Score: 18.867
#
# [기준서 10]
#   단어 '정책': Count = 2, TF-IDF = 0.306, Contribution = 0.612
#   단어 '개도국': Count = 0, TF-IDF = 0.247, Contribution = 0.000
#   단어 '철폐': Count = 0, TF-IDF = 0.187, Contribution = 0.000
#   단어 '송금': Count = 0, TF-IDF = 0.187, Contribution = 0.000
#   단어 '국가': Count = 4, TF-IDF = 0.173, Contribution = 0.693
#   단어 '비용': Count = 5, TF-IDF = 0.164, Contribution = 0.818
#   단어 '불평등': Count = 0, TF-IDF = 0.164, Contribution = 0.000
#   단어 '경제': Count = 8, TF-IDF = 0.149, Contribution = 1.191
#   단어 '규제': Count = 0, TF-IDF = 0.147, Contribution = 0.000
#   단어 '점진': Count = 0, TF-IDF = 0.147, Contribution = 0.000
# >> 기준서 10 Final Score: 3.314
#
# [기준서 11]
#   단어 '도시': Count = 1, TF-IDF = 0.388, Contribution = 0.388
#   단어 '재난': Count = 0, TF-IDF = 0.365, Contribution = 0.000
#   단어 '안전': Count = 2, TF-IDF = 0.220, Contribution = 0.439
#   단어 '포용': Count = 0, TF-IDF = 0.189, Contribution = 0.000
#   단어 '년': Count = 8, TF-IDF = 0.180, Contribution = 1.437
#   단어 '지속': Count = 52, TF-IDF = 0.161, Contribution = 8.362
#   단어 '접근': Count = 4, TF-IDF = 0.143, Contribution = 0.574
#   단어 '환경': Count = 161, TF-IDF = 0.142, Contribution = 22.790
#   단어 '폐기물': Count = 28, TF-IDF = 0.135, Contribution = 3.794
#   단어 '주의': Count = 0, TF-IDF = 0.135, Contribution = 0.000
# >> 기준서 11 Final Score: 37.784
#
# [기준서 12]
#   단어 '지속': Count = 52, TF-IDF = 0.321, Contribution = 16.714
#   단어 '소비': Count = 59, TF-IDF = 0.271, Contribution = 15.977
#   단어 '영향': Count = 42, TF-IDF = 0.236, Contribution = 9.902
#   단어 '양식': Count = 0, TF-IDF = 0.233, Contribution = 0.000
#   단어 '보조금': Count = 0, TF-IDF = 0.182, Contribution = 0.000
#   단어 '발생': Count = 71, TF-IDF = 0.182, Contribution = 12.934
#   단어 '생산': Count = 84, TF-IDF = 0.176, Contribution = 14.755
#   단어 '발전': Count = 4, TF-IDF = 0.164, Contribution = 0.657
#   단어 '식품': Count = 23, TF-IDF = 0.155, Contribution = 3.567
#   단어 '환경': Count = 161, TF-IDF = 0.141, Contribution = 22.775
# >> 기준서 12 Final Score: 97.281
#
# [기준서 13]
#   단어 '기후': Count = 49, TF-IDF = 0.539, Contribution = 26.407
#   단어 '변화': Count = 12, TF-IDF = 0.423, Contribution = 5.071
#   단어 '완화': Count = 0, TF-IDF = 0.169, Contribution = 0.000
#   단어 '영향': Count = 42, TF-IDF = 0.131, Contribution = 5.513
#   단어 '국가': Count = 4, TF-IDF = 0.120, Contribution = 0.479
#   단어 '긴급': Count = 0, TF-IDF = 0.108, Contribution = 0.000
#   단어 '인적': Count = 33, TF-IDF = 0.108, Contribution = 3.561
#   단어 '녹색': Count = 1, TF-IDF = 0.108, Contribution = 0.108
#   단어 '배경': Count = 4, TF-IDF = 0.108, Contribution = 0.432
#   단어 '의미': Count = 10, TF-IDF = 0.108, Contribution = 1.079
# >> 기준서 13 Final Score: 42.651
#
# [기준서 14]
#   단어 '해양': Count = 1, TF-IDF = 0.752, Contribution = 0.752
#   단어 '어업': Count = 0, TF-IDF = 0.177, Contribution = 0.000
#   단어 '보전': Count = 2, TF-IDF = 0.154, Contribution = 0.309
#   단어 '지속': Count = 52, TF-IDF = 0.147, Contribution = 7.628
#   단어 '자원': Count = 535, TF-IDF = 0.141, Contribution = 75.190
#   단어 '보조금': Count = 0, TF-IDF = 0.139, Contribution = 0.000
#   단어 '개도국': Count = 0, TF-IDF = 0.136, Contribution = 0.000
#   단어 '과학': Count = 0, TF-IDF = 0.116, Contribution = 0.000
#   단어 '이용': Count = 32, TF-IDF = 0.116, Contribution = 3.716
#   단어 '연안': Count = 0, TF-IDF = 0.088, Contribution = 0.000
# >> 기준서 14 Final Score: 87.596
#
# [기준서 15]
#   단어 '산림': Count = 2, TF-IDF = 0.445, Contribution = 0.889
#   단어 '생태계': Count = 9, TF-IDF = 0.278, Contribution = 2.499
#   단어 '생물': Count = 6, TF-IDF = 0.243, Contribution = 1.456
#   단어 '훼손': Count = 4, TF-IDF = 0.222, Contribution = 0.889
#   단어 '다양성': Count = 5, TF-IDF = 0.198, Contribution = 0.992
#   단어 '지속': Count = 52, TF-IDF = 0.184, Contribution = 9.587
#   단어 '복원': Count = 0, TF-IDF = 0.174, Contribution = 0.000
#   단어 '방지': Count = 1, TF-IDF = 0.167, Contribution = 0.167
#   단어 '사막화': Count = 0, TF-IDF = 0.167, Contribution = 0.000
#   단어 '토지': Count = 2, TF-IDF = 0.146, Contribution = 0.292
# >> 기준서 15 Final Score: 16.771
#
# [기준서 16]
#   단어 '제도': Count = 1, TF-IDF = 0.401, Contribution = 0.401
#   단어 '폭력': Count = 0, TF-IDF = 0.321, Contribution = 0.000
#   단어 '단계': Count = 19, TF-IDF = 0.241, Contribution = 4.571
#   단어 '형태': Count = 8, TF-IDF = 0.223, Contribution = 1.787
#   단어 '포용': Count = 0, TF-IDF = 0.168, Contribution = 0.000
#   단어 '감소': Count = 6, TF-IDF = 0.146, Contribution = 0.875
#   단어 '기관': Count = 2, TF-IDF = 0.144, Contribution = 0.288
#   단어 '불법': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '구축': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '책임': Count = 1, TF-IDF = 0.144, Contribution = 0.144
# >> 기준서 16 Final Score: 8.066
#
# [기준서 17]
#   단어 '파트너십': Count = 0, TF-IDF = 0.230, Contribution = 0.000
#   단어 '가능': Count = 0, TF-IDF = 0.196, Contribution = 0.000
#   단어 '발전': Count = 4, TF-IDF = 0.195, Contribution = 0.780
#   단어 '강화': Count = 0, TF-IDF = 0.193, Contribution = 0.000
#   단어 '부채': Count = 0, TF-IDF = 0.184, Contribution = 0.000
#   단어 '개도국': Count = 0, TF-IDF = 0.182, Contribution = 0.000
#   단어 '개발원조': Count = 0, TF-IDF = 0.161, Contribution = 0.000
#   단어 '이행': Count = 0, TF-IDF = 0.153, Contribution = 0.000
#   단어 '총': Count = 0, TF-IDF = 0.144, Contribution = 0.000
#   단어 '재원': Count = 0, TF-IDF = 0.144, Contribution = 0.000
# >> 기준서 17 Final Score: 0.780
#
# ===== Computed Category Scores =====
#          Year Category      Score
# 0   2015년 데이터    기준서 1   4.092963
# 1   2015년 데이터    기준서 2   2.041221
# 2   2015년 데이터    기준서 3   0.162892
# 3   2015년 데이터    기준서 4   8.201628
# 4   2015년 데이터    기준서 5   1.648419
# 5   2015년 데이터    기준서 6  33.890514
# 6   2015년 데이터    기준서 7  13.108930
# 7   2015년 데이터    기준서 8   8.777285
# 8   2015년 데이터    기준서 9   5.042646
# 9   2015년 데이터   기준서 10   0.148821
# 10  2015년 데이터   기준서 11   3.348899
# 11  2015년 데이터   기준서 12   5.153983
# 12  2015년 데이터   기준서 13  10.453449
# 13  2015년 데이터   기준서 14  55.221528
# 14  2015년 데이터   기준서 15   0.000000
# 15  2015년 데이터   기준서 16   5.024023
# 16  2015년 데이터   기준서 17   2.728529
# 17  2022년 데이터    기준서 1   5.238201
# 18  2022년 데이터    기준서 2   4.244380
# 19  2022년 데이터    기준서 3   1.520330
# 20  2022년 데이터    기준서 4   6.496753
# 21  2022년 데이터    기준서 5   1.531432
# 22  2022년 데이터    기준서 6  38.985169
# 23  2022년 데이터    기준서 7  45.284489
# 24  2022년 데이터    기준서 8  17.078141
# 25  2022년 데이터    기준서 9  18.866764
# 26  2022년 데이터   기준서 10   3.313503
# 27  2022년 데이터   기준서 11  37.783544
# 28  2022년 데이터   기준서 12  97.281138
# 29  2022년 데이터   기준서 13  42.650641
# 30  2022년 데이터   기준서 14  87.595630
# 31  2022년 데이터   기준서 15  16.771205
# 32  2022년 데이터   기준서 16   8.065708
# 33  2022년 데이터   기준서 17   0.779580
#
# ===== Detailed Word Counts and Contributions =====
#           Year Category  Word    TF-IDF  Count  Contribution
# 0    2015년 데이터    기준서 1    빈곤  0.529830      0      0.000000
# 1    2015년 데이터    기준서 1    계층  0.207171      0      0.000000
# 2    2015년 데이터    기준서 1    측면  0.193597      0      0.000000
# 3    2015년 데이터    기준서 1    동등  0.169045      1      0.169045
# 4    2015년 데이터    기준서 1     년  0.160031     14      2.240438
# ..         ...      ...   ...       ...    ...           ...
# 335  2022년 데이터   기준서 17   개도국  0.182003      0      0.000000
# 336  2022년 데이터   기준서 17  개발원조  0.160677      0      0.000000
# 337  2022년 데이터   기준서 17    이행  0.152567      0      0.000000
# 338  2022년 데이터   기준서 17     총  0.144120      0      0.000000
# 339  2022년 데이터   기준서 17    재원  0.144120      0      0.000000
#
# [340 rows x 6 columns]
# ===== Summary Statistics by Year =====
#         Year       mean      min        max     median
# 0  2015년 데이터   9.355631  0.00000  55.221528   5.024023
# 1  2022년 데이터  25.499212  0.77958  97.281138  16.771205

# %% [markdown]
# #딥러닝방법론

# %%
# !pip install transformers sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
import re

# 데이터 전처리 및 문장 분리 함수
def split_into_sentences(text, min_length=5):
    """
    텍스트 전처리 및 문장 분리:
    - 한글, 기본 구두점(마침표, 물음표, 느낌표)만 유지
    - 줄바꿈 -> 공백으로 대체
    - 공백 3개 이상 기준으로 분리
    - 구두점 기준으로 추가 분리
    - 최소 길이 조건으로 필터링
    """
    try:
        # 한글, 마침표, 물음표, 느낌표만 유지하고 나머지 제거
        text = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣.!?]', ' ', text)
        # 연속된 공백을 하나로 줄이기
        text = re.sub(r'\s+', ' ', text).strip()
        # 공백 3개 이상 기준으로 분리
        sentences = re.split(r'\s{3,}', text)
        # 각 문장별로 구두점 기준 추가 분리
        final_sentences = []
        for sentence in sentences:
            split_sentences = re.split(r'(?<=[.!?])\s+', sentence)
            final_sentences.extend(split_sentences)
        # 최소 길이 조건에 따라 필터링
        filtered_sentences = [s.strip() for s in final_sentences if len(s.strip()) >= min_length]
        return filtered_sentences
    except Exception as e:
        print(f"문장 전처리 및 분리 중 오류 발생: {e}")
        return []

# 2015년, 2022년 데이터를 문장 단위로 분할
sentences_2015 = split_into_sentences(text_data["2015년 데이터"])
sentences_2022 = split_into_sentences(text_data["2022년 데이터"])

# 카테고리 데이터를 문장 단위로 분할
category_sentences = [split_into_sentences(category) for category in categories]

# %%
# 문장 수 계산 및 출력
print(f"2015년 데이터 문장 수: {len(sentences_2015)}")
print(f"2022년 데이터 문장 수: {len(sentences_2022)}")

print("\n카테고리별 문장 수:")
for i, category in enumerate(category_sentences, start=1):
    print(f"문서 {i}: {len(category)} 문장")
# Out:
# 2015년 데이터 문장 수: 760
# 2022년 데이터 문장 수: 743
#
# 카테고리별 문장 수:
# 문서 1: 9 문장
# 문서 2: 9 문장
# 문서 3: 14 문장
# 문서 4: 11 문장
# 문서 5: 10 문장
# 문서 6: 9 문장
# 문서 7: 6 문장
# 문서 8: 13 문장
# 문서 9: 9 문장
# 문서 10: 11 문장
# 문서 11: 11 문장
# 문서 12: 12 문장
# 문서 13: 6 문장
# 문서 14: 11 문장
# 문서 15: 13 문장
# 문서 16: 14 문장
# 문서 17: 24 문장

# %%
from sentence_transformers import SentenceTransformer, util
import torch

# SBERT 모델 초기화
model = SentenceTransformer('sentence-transformers/xlm-r-large-en-ko-nli-ststb')  # 한국어 SBERT

# 2015년, 2022년 문장 임베딩 실행
print("2015년 문장 임베딩 생성 중...")
embeddings_2015 = model.encode(sentences_2015, convert_to_tensor=True)

print("2022년 문장 임베딩 생성 중...")
embeddings_2022 = model.encode(sentences_2022, convert_to_tensor=True)

# 문서 1~17의 문장 임베딩 실행
category_embeddings = []
for i, category_sentences_group in enumerate(category_sentences, start=1):
    print(f"문서 {i} 문장 임베딩 생성 중...")
    category_embeddings.append(model.encode(category_sentences_group, convert_to_tensor=True))

# 임베딩 크기 확인
print("\n임베딩 크기:")
print("2015년 문장 임베딩 크기:", embeddings_2015.size())
print("2022년 문장 임베딩 크기:", embeddings_2022.size())
for i, embedding in enumerate(category_embeddings, start=1):
    print(f"문서 {i} 문장 임베딩 크기:", embedding.size())
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.01k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/733 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# 2015년 문장 임베딩 생성 중...
# 2022년 문장 임베딩 생성 중...
# 문서 1 문장 임베딩 생성 중...
# 문서 2 문장 임베딩 생성 중...
# 문서 3 문장 임베딩 생성 중...
# 문서 4 문장 임베딩 생성 중...
# 문서 5 문장 임베딩 생성 중...
# 문서 6 문장 임베딩 생성 중...
# 문서 7 문장 임베딩 생성 중...
# 문서 8 문장 임베딩 생성 중...
# 문서 9 문장 임베딩 생성 중...
# 문서 10 문장 임베딩 생성 중...
# 문서 11 문장 임베딩 생성 중...
# 문서 12 문장 임베딩 생성 중...
# 문서 13 문장 임베딩 생성 중...
# 문서 14 문장 임베딩 생성 중...
# 문서 15 문장 임베딩 생성 중...
# 문서 16 문장 임베딩 생성 중...
# 문서 17 문장 임베딩 생성 중...
#
# 임베딩 크기:
# 2015년 문장 임베딩 크기: torch.Size([760, 1024])
# 2022년 문장 임베딩 크기: torch.Size([743, 1024])
# 문서 1 문장 임베딩 크기: torch.Size([9, 1024])
# 문서 2 문장 임베딩 크기: torch.Size([9, 1024])
# 문서 3 문장 임베딩 크기: torch.Size([14, 1024])
# 문서 4 문장 임베딩 크기: torch.Size([11, 1024])
# 문서 5 문장 임베딩 크기: torch.Size([10, 1024])
# 문서 6 문장 임베딩 크기: torch.Size([9, 1024])
# 문서 7 문장 임베딩 크기: torch.Size([6, 1024])
# 문서 8 문장 임베딩 크기: torch.Size([13, 1024])
# 문서 9 문장 임베딩 크기: torch.Size([9, 1024])
# 문서 10 문장 임베딩 크기: torch.Size([11, 1024])
# 문서 11 문장 임베딩 크기: torch.Size([11, 1024])
# 문서 12 문장 임베딩 크기: torch.Size([12, 1024])
# 문서 13 문장 임베딩 크기: torch.Size([6, 1024])
# 문서 14 문장 임베딩 크기: torch.Size([11, 1024])
# 문서 15 문장 임베딩 크기: torch.Size([13, 1024])
# 문서 16 문장 임베딩 크기: torch.Size([14, 1024])
# 문서 17 문장 임베딩 크기: torch.Size([24, 1024])

# %%
# 문서 1~17 유사도 계산 및 저장
similarities_by_document = {}

for i, doc_embedding in enumerate(category_embeddings, start=1):
    print(f"\n문서 {i} 유사도 계산 중...")

    # 문서와 2015년도 데이터 간 유사도 계산
    similarities_2015 = util.pytorch_cos_sim(doc_embedding, embeddings_2015)

    # 문서와 2022년도 데이터 간 유사도 계산
    similarities_2022 = util.pytorch_cos_sim(doc_embedding, embeddings_2022)

    # 유사도 결과 저장
    similarities_by_document[f"문서 {i}"] = {
        "2015": similarities_2015,
        "2022": similarities_2022
    }
# Out:
# 문서 1 유사도 계산 중...
#
# 문서 2 유사도 계산 중...
#
# 문서 3 유사도 계산 중...
#
# 문서 4 유사도 계산 중...
#
# 문서 5 유사도 계산 중...
#
# 문서 6 유사도 계산 중...
#
# 문서 7 유사도 계산 중...
#
# 문서 8 유사도 계산 중...
#
# 문서 9 유사도 계산 중...
#
# 문서 10 유사도 계산 중...
#
# 문서 11 유사도 계산 중...
#
# 문서 12 유사도 계산 중...
#
# 문서 13 유사도 계산 중...
#
# 문서 14 유사도 계산 중...
#
# 문서 15 유사도 계산 중...
#
# 문서 16 유사도 계산 중...
#
# 문서 17 유사도 계산 중...

# %%
# 문서별 유사도 결과 출력
for doc, data in similarities_by_document.items():
    print(f"\n{doc} 유사도 결과:")

    # 2015년도 유사도 분석
    avg_similarity_2015 = torch.mean(data["2015"])
    max_similarity_2015 = torch.max(data["2015"])
    print(f"2015년도와의 평균 유사도: {avg_similarity_2015:.4f}, 최대 유사도: {max_similarity_2015:.4f}")

    # 2022년도 유사도 분석
    avg_similarity_2022 = torch.mean(data["2022"])
    max_similarity_2022 = torch.max(data["2022"])
    print(f"2022년도와의 평균 유사도: {avg_similarity_2022:.4f}, 최대 유사도: {max_similarity_2022:.4f}")
# Out:
# 문서 1 유사도 결과:
# 2015년도와의 평균 유사도: 0.2442, 최대 유사도: 0.7073
# 2022년도와의 평균 유사도: 0.2621, 최대 유사도: 0.7516
#
# 문서 2 유사도 결과:
# 2015년도와의 평균 유사도: 0.2191, 최대 유사도: 0.7172
# 2022년도와의 평균 유사도: 0.3024, 최대 유사도: 0.8402
#
# 문서 3 유사도 결과:
# 2015년도와의 평균 유사도: 0.2131, 최대 유사도: 0.7848
# 2022년도와의 평균 유사도: 0.2425, 최대 유사도: 0.7405
#
# 문서 4 유사도 결과:
# 2015년도와의 평균 유사도: 0.3021, 최대 유사도: 0.7506
# 2022년도와의 평균 유사도: 0.2541, 최대 유사도: 0.7787
#
# 문서 5 유사도 결과:
# 2015년도와의 평균 유사도: 0.1985, 최대 유사도: 0.8053
# 2022년도와의 평균 유사도: 0.2146, 최대 유사도: 0.7270
#
# 문서 6 유사도 결과:
# 2015년도와의 평균 유사도: 0.2483, 최대 유사도: 0.6468
# 2022년도와의 평균 유사도: 0.3177, 최대 유사도: 0.8344
#
# 문서 7 유사도 결과:
# 2015년도와의 평균 유사도: 0.2969, 최대 유사도: 0.6745
# 2022년도와의 평균 유사도: 0.2853, 최대 유사도: 0.7478
#
# 문서 8 유사도 결과:
# 2015년도와의 평균 유사도: 0.2739, 최대 유사도: 0.6861
# 2022년도와의 평균 유사도: 0.2668, 최대 유사도: 0.8085
#
# 문서 9 유사도 결과:
# 2015년도와의 평균 유사도: 0.2818, 최대 유사도: 0.7353
# 2022년도와의 평균 유사도: 0.3030, 최대 유사도: 0.8138
#
# 문서 10 유사도 결과:
# 2015년도와의 평균 유사도: 0.2566, 최대 유사도: 0.7061
# 2022년도와의 평균 유사도: 0.2566, 최대 유사도: 0.7194
#
# 문서 11 유사도 결과:
# 2015년도와의 평균 유사도: 0.2689, 최대 유사도: 0.7396
# 2022년도와의 평균 유사도: 0.3076, 최대 유사도: 0.8557
#
# 문서 12 유사도 결과:
# 2015년도와의 평균 유사도: 0.2819, 최대 유사도: 0.7354
# 2022년도와의 평균 유사도: 0.3445, 최대 유사도: 0.9116
#
# 문서 13 유사도 결과:
# 2015년도와의 평균 유사도: 0.2648, 최대 유사도: 0.6673
# 2022년도와의 평균 유사도: 0.3254, 최대 유사도: 0.8503
#
# 문서 14 유사도 결과:
# 2015년도와의 평균 유사도: 0.2377, 최대 유사도: 0.7164
# 2022년도와의 평균 유사도: 0.2999, 최대 유사도: 0.7853
#
# 문서 15 유사도 결과:
# 2015년도와의 평균 유사도: 0.2368, 최대 유사도: 0.7012
# 2022년도와의 평균 유사도: 0.3208, 최대 유사도: 0.7993
#
# 문서 16 유사도 결과:
# 2015년도와의 평균 유사도: 0.2342, 최대 유사도: 0.7243
# 2022년도와의 평균 유사도: 0.2369, 최대 유사도: 0.7309
#
# 문서 17 유사도 결과:
# 2015년도와의 평균 유사도: 0.2677, 최대 유사도: 0.7787
# 2022년도와의 평균 유사도: 0.2732, 최대 유사도: 0.7482

# %%
import matplotlib.pyplot as plt

# 문서별 유사도 히스토그램
for doc, data in similarities_by_document.items():
    plt.figure(figsize=(12, 6))
    plt.hist(data["2015"].flatten().cpu().numpy(), bins=50, alpha=0.7, label="2015년 유사도")
    plt.hist(data["2022"].flatten().cpu().numpy(), bins=50, alpha=0.7, label="2022년 유사도")
    plt.title(f"{doc} 유사도 분포 (2015년 vs 2022년)", fontsize=14, fontweight="bold")
    plt.xlabel("유사도", fontsize=12)
    plt.ylabel("빈도", fontsize=12)
    plt.legend(fontsize=12)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #jhgan/ko-sroberta-multitask

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sentence_transformers import SentenceTransformer, util

# --------------------------
# 1. 모델 로드 (한국어 최적 모델)
# --------------------------
model = SentenceTransformer("sentence-transformers/xlm-r-large-en-ko-nli-ststb")

# --------------------------
# 2. 미리 분할된 문장 리스트가 있다고 가정
#    - sentences_2015: 2015년도 문장 리스트
#    - sentences_2022: 2022년도 문장 리스트
#    - category_sentences: 기준서(문서 1~17)별 문장 리스트 (리스트 안에 17개의 리스트)
# --------------------------

# 2015, 2022년도 문장의 임베딩을 미리 계산 (한번에 계산)
embeddings_2015 = model.encode(sentences_2015, convert_to_tensor=True)
embeddings_2022 = model.encode(sentences_2022, convert_to_tensor=True)

# --------------------------
# 3. 각 기준서 문서(문서 1~17)와 각 연도(2015, 2022) 문장 간의 유사도 계산 및 분석
# --------------------------
for cat_idx, cat_sent_list in enumerate(category_sentences, start=1):
    print(f"\n===== 기준서 문서 {cat_idx} =====")

    # 기준서 문장의 임베딩 계산
    cat_embeddings = model.encode(cat_sent_list, convert_to_tensor=True)

    # 연도별로 처리 (2015년과 2022년)
    for year_label, year_embeddings, year_sentences in zip(
        ["2015년", "2022년"],
        [embeddings_2015, embeddings_2022],
        [sentences_2015, sentences_2022]
    ):
        print(f"\n--- {year_label} ---")

        # 기준서 문장과 해당 연도 문장 사이의 코사인 유사도 행렬 계산
        # sim_matrix.shape = (len(cat_sent_list), len(year_sentences))
        sim_matrix = util.cos_sim(cat_embeddings, year_embeddings)

        # 전체 유사도 값을 1차원 배열로 변환
        sim_scores = sim_matrix.cpu().numpy().flatten()

        # 유사도 통계 계산
        mean_sim = np.mean(sim_scores)
        min_sim = np.min(sim_scores)
        max_sim = np.max(sim_scores)
        # 최빈값 계산: 소수점 둘째자리로 반올림하여 빈도수 집계
        rounded_scores = np.round(sim_scores, 2)
        counter = collections.Counter(rounded_scores)
        mode_val, mode_count = counter.most_common(1)[0]

        print(f"유사도 통계 - 평균: {mean_sim:.3f}, 최소: {min_sim:.3f}, 최대: {max_sim:.3f}, 최빈값: {mode_val} (빈도: {mode_count})")

        # --------------------------
        # 3-1. 박스플롯으로 유사도 분포 시각화
        # --------------------------
        plt.figure(figsize=(6,4))
        sns.boxplot(x=sim_scores)
        plt.title(f"기준서 {cat_idx} - {year_label} 유사도 박스플롯")
        plt.xlabel("코사인 유사도")
        plt.show()

        # --------------------------
        # 3-2. 히스토그램으로 구간별 문장 수 시각화
        # --------------------------
        plt.figure(figsize=(6,4))
        bins = np.linspace(0, 1, 21)  # 0~1 범위를 20 구간으로 나눔
        plt.hist(sim_scores, bins=bins, edgecolor='black')
        plt.title(f"기준서 {cat_idx} - {year_label} 유사도 분포")
        plt.xlabel("코사인 유사도")
        plt.ylabel("문장 개수")
        plt.show()

        # --------------------------
        # 3-3. 가장 유사한 문장 쌍 찾기
        # --------------------------
        max_idx = np.argmax(sim_scores)
        # 2차원 행렬 인덱스로 변환: 행(기준서 문장 인덱스), 열(연도 문장 인덱스)
        num_year = sim_matrix.shape[1]
        cat_sentence_index = max_idx // num_year
        year_sentence_index = max_idx % num_year
        highest_sim = sim_scores[max_idx]

        print(f"\n가장 유사한 문장 쌍 (유사도 {highest_sim:.3f}):")
        print(" [기준서 문장]:", cat_sent_list[cat_sentence_index])
        print(" [연도 문장]:", year_sentences[year_sentence_index])
# Out:
# ===== 기준서 문서 1 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.244, 최소: -0.192, 최대: 0.707, 최빈값: 0.23000000417232513 (빈도: 182)
# 가장 유사한 문장 쌍 (유사도 0.707):
#  [기준서 문장]: 개도국 특히 최빈개도국에게 모든 측면에서 빈곤을 종식하기 위한 프로그램과 정책을 이행할 수 있는 적절하고 예측 가능한 수단을 제공하기 위하여 개발 협력 증진 등을 통한 다양한 원천으로부터의 자원의 상당한 동원을 보장한다.
#  [연도 문장]: 따라서 생활 자원을 적절히 배분하여 사용함 으로써 자신과 가족의 욕구를 최대한 충족시키고 생활의 질을 향상시킬 수 있도 록 한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.262, 최소: -0.254, 최대: 0.752, 최빈값: 0.28999999165534973 (빈도: 172)
# 가장 유사한 문장 쌍 (유사도 0.752):
#  [기준서 문장]: 년까지 빈곤층과 취약계층의 회복력을 구축하고 극한 기후에 관련된 사건이나 기타 경제 사회 환경적 충격 및 재난에 대한 노출과 취약성을 감소한다.
#  [연도 문장]: 그림 그러므로 자원의 낭비를 최소화하고 환경에 미치는 부정적인 영향과 폐기되는 자원을 줄이려고 노력해야 한다.
#
# ===== 기준서 문서 2 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.219, 최소: -0.212, 최대: 0.717, 최빈값: 0.20000000298023224 (빈도: 213)
# 가장 유사한 문장 쌍 (유사도 0.717):
#  [기준서 문장]: 년까지 기아를 종식시키고 영유아를 포함한 모든 사람 특히 빈곤층과 취약계층이 연중 안전하고 영양가 있는 충분한 식량에 대한 접근을 보장한다.
#  [연도 문장]: 예를 들어 시간이 부족한 사람이라면 돈이라는 물적 자원 을 활용하여 음식을 사 먹어 시간을 절약할 수 있다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.302, 최소: -0.216, 최대: 0.840, 최빈값: 0.38999998569488525 (빈도: 171)
# 가장 유사한 문장 쌍 (유사도 0.840):
#  [기준서 문장]: 식료품 시장 및 파생상품 시장의 적절한 기능을 보장할 수 있는 방안을 채택하고 과도한 식량가격의 변동성을 제한할 수 있도록 식량 저장과 같은 시장 정보에의 적시 접근을 원활하게하기 위한 조치를 채택한다.
#  [연도 문장]: 식품의 알맞은 보관 방법을 통해 음식물 쓰레기 발생을 줄인다.
#
# ===== 기준서 문서 3 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.213, 최소: -0.182, 최대: 0.785, 최빈값: 0.18000000715255737 (빈도: 315)
# 가장 유사한 문장 쌍 (유사도 0.785):
#  [기준서 문장]: 모든 연령층을 위한 건강한 삶 보장과 웰빙 증진 .
#  [연도 문장]: .생활자원의 특성 위와 같이 우리의 생명과 건강을 유지하고 욕구를 충족하며 목표를 이루기 위해 사용하는 모든 자원을 생활 자원이라고 한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.243, 최소: -0.188, 최대: 0.740, 최빈값: 0.2199999988079071 (빈도: 293)
# 가장 유사한 문장 쌍 (유사도 0.740):
#  [기준서 문장]: 년까지 유해 화학물질 대기 수질 토지 공해 및 오염으로 인한 사망과 질병 건수를 상당히 감소한다.
#  [연도 문장]: 쓰레기를 줄여 낭비되는 자원을 줄이고 오염 물질을 최소화하는 것을 의미한다.
#
# ===== 기준서 문서 4 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.302, 최소: -0.217, 최대: 0.751, 최빈값: 0.33000001311302185 (빈도: 245)
# 가장 유사한 문장 쌍 (유사도 0.751):
#  [기준서 문장]: 년까지 취업 양질의 일자리 창업 활동에 필요한 전문 직업 기술 등 적합한 기술을 지닌 청소년과 성인의 수를 실질적으로 늘린다.
#  [연도 문장]: 청소년의 자원 관리 청소년의 학업 관리 관리 청소년기는 일상생활을 위한 기본적 지식과 향후 진학과 진로를 결정하는 데 필요한 전문 적 지식을 함양하는 매우 중요한 시기이다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.254, 최소: -0.220, 최대: 0.779, 최빈값: 0.25999999046325684 (빈도: 246)
# 가장 유사한 문장 쌍 (유사도 0.779):
#  [기준서 문장]: 년까지 취업 양질의 일자리 창업 활동에 필요한 전문 직업 기술 등 적합한 기술을 지닌 청소년과 성인의 수를 실질적으로 늘린다.
#  [연도 문장]: 인적 자원 계발하기 꾸준한 노력으로 지식 기술 창의력 등의 인적 자원을 늘린다.
#
# ===== 기준서 문서 5 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.198, 최소: -0.168, 최대: 0.805, 최빈값: 0.07999999821186066 (빈도: 220)
# 가장 유사한 문장 쌍 (유사도 0.805):
#  [기준서 문장]: 공공서비스 사회기반시설 및 사회적 보호정책을 제공하고 국가별로 적절하게 가구와 가족 내에서의 책임 분담을 증진함으로써 무상 돌봄과 가사노동을 인정하고 가치 있게 인식한다.
#  [연도 문장]: 생활 자원의 특성 생활 자원이란 나와 가족의 욕구를 충족시키고 목표를 달성하는 데 활용할 수 있는 수단과 방법이다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.215, 최소: -0.156, 최대: 0.727, 최빈값: 0.17000000178813934 (빈도: 232)
# 가장 유사한 문장 쌍 (유사도 0.727):
#  [기준서 문장]: 공공서비스 사회기반시설 및 사회적 보호정책을 제공하고 국가별로 적절하게 가구와 가족 내에서의 책임 분담을 증진함으로써 무상 돌봄과 가사노동을 인정하고 가치 있게 인식한다.
#  [연도 문장]: 그중 일상생활에서 나와 가족의 욕구를 충족하고 목표를 달성하기 위해 활용 할 수 있는 모든 수단이나 방법을 생활 자원이라고 한다.
#
# ===== 기준서 문서 6 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.248, 최소: -0.200, 최대: 0.647, 최빈값: 0.2199999988079071 (빈도: 240)
# 가장 유사한 문장 쌍 (유사도 0.647):
#  [기준서 문장]: 년까지 집수 담수화 물 효율성 폐수처리 재활용 및 재사용 기술을 포함하는 물과 위생 관련 활동과 프로그램에 있어 개도국 역량 강화 지원과 국제적 협력을 확대한다.
#  [연도 문장]: 생 생 활 여 리 물 가 모 적 정 기 선 달 물 인 력 장 시 물 목 차 표 적 물 간 할 일 목 록 노 동 리 평 가 관 생 여 가 치 장 활 산 정 적 자 원 선 지 간 원 실 순 정 복 지 행 위 가 청 소 적 자 원 디 자 년 자 원 관 리 와 자 나와 가족의 욕구를 충족시키고 목표를 달성하는 데 활용할 수 있는 수단과 방법 립 개인이 가진 특성이나 능력에 관련된 자원으로 노력에 따라 높은 수준으로 발전할 수 있는 자원 양과 질을 쉽게 측정할 수 있는 생활 자원 생활하는 데 필요한 에너지를 생산하고 건강한 생명을 유지하는 데 필요한 시간을 생활시간이라고 한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.318, 최소: -0.155, 최대: 0.834, 최빈값: 0.3499999940395355 (빈도: 182)
# 가장 유사한 문장 쌍 (유사도 0.834):
#  [기준서 문장]: 년까지 오염 저감 유해물질의 투기 근절과 배출 최소화 미처리 폐수 비율 반감 전 세계에서 재활용과 안전한 재사용의 대폭 증진을 통해 수질을 개선한다.
#  [연도 문장]: 환경을 위한 노력 친환경 해체 기술을 적용하여 환경 오염 을 최소화한다.
#
# ===== 기준서 문서 7 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.297, 최소: -0.181, 최대: 0.675, 최빈값: 0.33000001311302185 (빈도: 134)
# 가장 유사한 문장 쌍 (유사도 0.675):
#  [기준서 문장]: 년까지 개도국 특히 최빈개도국 군소도서개도국 및 내륙개도국에서 각국의 지원 프로그램에 따라 모두를 위한 현대적이고 지속가능한 에너지 서비스를 공급하기 위한 기반시설을 확대하고 기술을 개선한다.
#  [연도 문장]: 인적 자원을 최대한 것 지식 기술 창의력 판단력 등의 인적 자원을 꾸준히 개발하여 활용한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.285, 최소: -0.176, 최대: 0.748, 최빈값: 0.28999999165534973 (빈도: 132)
# 가장 유사한 문장 쌍 (유사도 0.748):
#  [기준서 문장]: 년까지 개도국 특히 최빈개도국 군소도서개도국 및 내륙개도국에서 각국의 지원 프로그램에 따라 모두를 위한 현대적이고 지속가능한 에너지 서비스를 공급하기 위한 기반시설을 확대하고 기술을 개선한다.
#  [연도 문장]: 인적 자원 계발하기 꾸준한 노력으로 지식 기술 창의력 등의 인적 자원을 늘린다.
#
# ===== 기준서 문서 8 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.274, 최소: -0.238, 최대: 0.686, 최빈값: 0.3400000035762787 (빈도: 272)
# 가장 유사한 문장 쌍 (유사도 0.686):
#  [기준서 문장]: 년까지 청년 고용을 위한 글로벌 전략을 개발하고 운영하며 국제노동 기구 세계고용협약 을 이행한다.
#  [연도 문장]: 청소년의 자원 관리 청소년의 학업 관리 관리 청소년기는 일상생활을 위한 기본적 지식과 향후 진학과 진로를 결정하는 데 필요한 전문 적 지식을 함양하는 매우 중요한 시기이다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.267, 최소: -0.223, 최대: 0.808, 최빈값: 0.2199999988079071 (빈도: 258)
# 가장 유사한 문장 쌍 (유사도 0.808):
#  [기준서 문장]: 지속가능한 소비와 생산에 관한 개년 계획에 따라 선진국들이 주도하여 소비와 생산에 있어서의 전 세계적인 자원 효율성을 년까지 점진적으로 개선하고 경제성장을 환경 악화로부터 분리시키도록 노력한다.
#  [연도 문장]: 기대하는 목표 세우기 환경 오염과 기후 위기를 극복할 수 있도록 의식주 생활 자원을 선택할 때 기대하는 목표를 세워 보자.
#
# ===== 기준서 문서 9 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.282, 최소: -0.199, 최대: 0.735, 최빈값: 0.25999999046325684 (빈도: 194)
# 가장 유사한 문장 쌍 (유사도 0.735):
#  [기준서 문장]: 모두를 위한 적정가격의 공평한 접근에 중점을 두고 경제발전과 인류의 웰빙을 지원하기 위해 지역별 및 초국경 사회기반시설을 포함하여 양질의 신뢰할 수 있고 지속가능하며 복원력 있는 사회기반시설을 구축한다.
#  [연도 문장]: 따라서 생활 자원을 적절히 배분하여 사용함 으로써 자신과 가족의 욕구를 최대한 충족시키고 생활의 질을 향상시킬 수 있도 록 한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.303, 최소: -0.210, 최대: 0.814, 최빈값: 0.30000001192092896 (빈도: 175)
# 가장 유사한 문장 쌍 (유사도 0.814):
#  [기준서 문장]: 모두를 위한 적정가격의 공평한 접근에 중점을 두고 경제발전과 인류의 웰빙을 지원하기 위해 지역별 및 초국경 사회기반시설을 포함하여 양질의 신뢰할 수 있고 지속가능하며 복원력 있는 사회기반시설을 구축한다.
#  [연도 문장]: 그 러므로 의식주 자원을 관리할 때 인간의 욕구 충족 및 목표 달성이라는 가치와 환 경 보전이라는 가치가 서로 적절히 조화를 이룰 수 있도록 해야 한다.
#
# ===== 기준서 문서 10 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.257, 최소: -0.212, 최대: 0.706, 최빈값: 0.23999999463558197 (빈도: 238)
# 가장 유사한 문장 쌍 (유사도 0.706):
#  [기준서 문장]: 계획되고 잘 관리된 이주정책 이행 등을 통하여 질서 있고 안전하며 정기적이고 책임감 있는 이주와 사람의 이동을 촉진한다.
#  [연도 문장]: 따라서 합리적인 계획과 실천을 통해 자신의 생활을 효율적으로 관리하고 미래의 인생을 설계 하고 준비할 수 있도록 한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.257, 최소: -0.155, 최대: 0.719, 최빈값: 0.23000000417232513 (빈도: 254)
# 가장 유사한 문장 쌍 (유사도 0.719):
#  [기준서 문장]: 계획되고 잘 관리된 이주정책 이행 등을 통하여 질서 있고 안전하며 정기적이고 책임감 있는 이주와 사람의 이동을 촉진한다.
#  [연도 문장]: 생활 자원의 순환 과정을 이해하고 생활 자원을 효율적으로 관리할 수 있다.
#
# ===== 기준서 문서 11 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.269, 최소: -0.173, 최대: 0.740, 최빈값: 0.28999999165534973 (빈도: 250)
# 가장 유사한 문장 쌍 (유사도 0.740):
#  [기준서 문장]: 년까지 모두를 위한 적절하고 안전한 적정가격의 주택 및 기초서비스에 대한 접근을 보장하고 빈민가 환경을 개선한다.
#  [연도 문장]: 따라서 생활 자원을 적절히 배분하여 사용함 으로써 자신과 가족의 욕구를 최대한 충족시키고 생활의 질을 향상시킬 수 있도 록 한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.308, 최소: -0.148, 최대: 0.856, 최빈값: 0.25999999046325684 (빈도: 220)
# 가장 유사한 문장 쌍 (유사도 0.856):
#  [기준서 문장]: 년까지 대기질 도시생활 폐기물 및 기타 폐기물 관리에 특별한 주의를 기울임으로써 도시의 인당 부정적 환경영향을 줄인다.
#  [연도 문장]: 쓰레기 배출량을 에 가깝게 줄여 환경을 보호하는 실천 운동이지.
#
# ===== 기준서 문서 12 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.282, 최소: -0.175, 최대: 0.735, 최빈값: 0.28999999165534973 (빈도: 238)
# 가장 유사한 문장 쌍 (유사도 0.735):
#  [기준서 문장]: 년까지 유통 및 소비자 수준에서의 전 세계 인구 인당 음식물쓰레기 발생량을 절반으로 줄이고 출하 후 손실을 포함한 식품의 생산 및 공급망에서 발생하는 식품 손실을 감소한다.
#  [연도 문장]: 예를 들어 시간이 부족한 사람이라면 돈이라는 물적 자원 을 활용하여 음식을 사 먹어 시간을 절약할 수 있다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.345, 최소: -0.187, 최대: 0.912, 최빈값: 0.3400000035762787 (빈도: 215)
# 가장 유사한 문장 쌍 (유사도 0.912):
#  [기준서 문장]: 년까지 예방 감축 재활용 및 재사용을 통해 폐기물 발생을 상당히 줄인다.
#  [연도 문장]: 쓰레기를 줄여 낭비되는 자원을 줄이고 오염 물질을 최소화하는 것을 의미한다.
#
# ===== 기준서 문서 13 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.265, 최소: -0.145, 최대: 0.667, 최빈값: 0.27000001072883606 (빈도: 145)
# 가장 유사한 문장 쌍 (유사도 0.667):
#  [기준서 문장]: 기후변화의 완화 적응 영향 감소 조기 경보 등에 관한 교육 인식제고 인적 제도적 역량을 강화한다.
#  [연도 문장]: .청소년의 자원관리 재 미 있 는 가 정 활 동 평소 자신의 하루 생활시간을 적어 보고 문제점을 분석한 후 삶의 질을 향상하기 위한 방법을 알아보자.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.325, 최소: -0.158, 최대: 0.850, 최빈값: 0.3799999952316284 (빈도: 128)
# 가장 유사한 문장 쌍 (유사도 0.850):
#  [기준서 문장]: 기후변화 대응조치를 국가 정책 전략 및 계획에 통합한다.
#  [연도 문장]: 기후 위기 문제를 해결하기 위해 국가나 지역 단체 기업 등에서 하고 있는 노력을 조사해 보자.
#
# ===== 기준서 문서 14 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.238, 최소: -0.179, 최대: 0.716, 최빈값: 0.20999999344348907 (빈도: 269)
# 가장 유사한 문장 쌍 (유사도 0.716):
#  [기준서 문장]: 년까지 심각한 악영향을 피하고자 회복력을 강화하는 방법을 포함하여 해양과 연안의 생태계를 지속가능하게 관리하고 보호하며 건강하고 생산적인 해양을 조성하기 위해 복원 조치를 시행한다.
#  [연도 문장]: 물품은 깨끗이 사용하고 고장이 나면 바로 수리하는 등 자원을 잘 관리하면 더 오래 사용할 수 있다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.300, 최소: -0.199, 최대: 0.785, 최빈값: 0.2800000011920929 (빈도: 225)
# 가장 유사한 문장 쌍 (유사도 0.785):
#  [기준서 문장]: 년까지 해양 쓰레기와 영양염류 오염을 포함하여 특히 육상활동에서 발생하는 모든 종류의 해양 오염을 예방하고 상당한 수준으로 줄인다.
#  [연도 문장]: 환경을 위한 노력 친환경 해체 기술을 적용하여 환경 오염 을 최소화한다.
#
# ===== 기준서 문서 15 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.237, 최소: -0.189, 최대: 0.701, 최빈값: 0.23000000417232513 (빈도: 321)
# 가장 유사한 문장 쌍 (유사도 0.701):
#  [기준서 문장]: 년까지 생태계와 생물다양성의 가치를 국가 지역 계획 개발 프로세스 및 빈곤감소 전략과 회계 에 통합한다.
#  [연도 문장]: 그림 자원의 효율적인 관리 방법 내가 가지고 있는 생활 자원을 분류하고 관리 계획을 세워 보자.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.321, 최소: -0.271, 최대: 0.799, 최빈값: 0.41999998688697815 (빈도: 242)
# 가장 유사한 문장 쌍 (유사도 0.799):
#  [기준서 문장]: 년까지 생태계와 생물다양성의 가치를 국가 지역 계획 개발 프로세스 및 빈곤감소 전략과 회계 에 통합한다.
#  [연도 문장]: 생활 자원의 순환과 의식주 자원 관리 의식주 생활 자원의 선택 과정과 결과의 성찰 의식주 생활 자원의 선택이 환경에 미치는 영향은 그림 과 같은 실천적 추 론 과정에 따라 성찰해 볼 수 있다.
#
# ===== 기준서 문서 16 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.234, 최소: -0.201, 최대: 0.724, 최빈값: 0.23000000417232513 (빈도: 278)
# 가장 유사한 문장 쌍 (유사도 0.724):
#  [기준서 문장]: 효과적이고 책임성 있으며 투명한 제도를 모든 단계의 기관에 구축한다.
#  [연도 문장]: 목표 세우기 명확하고 구체적으로 목표를 정한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.237, 최소: -0.174, 최대: 0.731, 최빈값: 0.1899999976158142 (빈도: 305)
# 가장 유사한 문장 쌍 (유사도 0.731):
#  [기준서 문장]: 지속가능발전을 위한 평화롭고 포용적인 사회 증진 모두에게 정의 보장과 모든 수준에서 효과적이고 책임성 있으며 포용적인 제도 구축 .
#  [연도 문장]: 이러한 일상생활 속 작은 선택들이 쌓여 환경을 보호할 수 있으며 기후 위기에 취약한 사회적 약자를 보호함으로써 함께 살아가는 사회적 가치를 실현할 수 있다.
#
# ===== 기준서 문서 17 =====
#
# --- 2015년 ---
# 유사도 통계 - 평균: 0.268, 최소: -0.206, 최대: 0.779, 최빈값: 0.2800000011920929 (빈도: 479)
# 가장 유사한 문장 쌍 (유사도 0.779):
#  [기준서 문장]: 파트너십의 경험과 재원조달 전략을 바탕으로 효과적인 공공 민관 시민사회의 파트너십을 장려하고 도모한다.
#  [연도 문장]: 다른 사람들과의 협동을 통해 대인적 자원을 계발한다.
#
# --- 2022년 ---
# 유사도 통계 - 평균: 0.273, 최소: -0.202, 최대: 0.748, 최빈값: 0.28999999165534973 (빈도: 473)
# 가장 유사한 문장 쌍 (유사도 0.748):
#  [기준서 문장]: 제공을 목표로 설정하는 것을 고려하도록 장려한다.
#  [연도 문장]: 가치 태도 의식주 생활 자원의 순환을 위해 우리가 할 수 있는 일을 이야기해 보자.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import collections
import re
from sentence_transformers import SentenceTransformer, util

# ====================================
# 1. 문장 분리 함수 (전처리)
# ====================================
def split_into_sentences(text, min_length=5):
    """
    텍스트 전처리 및 문장 분리:
    - 한글, 마침표, 물음표, 느낌표만 남김
    - 줄바꿈은 공백으로 대체 후, 연속 공백 줄이기
    - 공백 3개 이상 기준 분리 후, 구두점 기준 추가 분리
    - 최소 길이 조건 필터링
    """
    try:
        text = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣.!?]', ' ', text)
        text = re.sub(r'\s+', ' ', text).strip()
        sentences = re.split(r'\s{3,}', text)
        final_sentences = []
        for sentence in sentences:
            split_sentences = re.split(r'(?<=[.!?])\s+', sentence)
            final_sentences.extend(split_sentences)
        filtered_sentences = [s.strip() for s in final_sentences if len(s.strip()) >= min_length]
        return filtered_sentences
    except Exception as e:
        print(f"문장 분리 중 오류: {e}")
        return []

# 이미 준비된 text_data, categories 변수가 있다고 가정합니다.
# 예시:
# text_data = {"2015년 데이터": "…", "2022년 데이터": "…"}
# categories = [기준서1, 기준서2, ..., 기준서17]

# 2015년, 2022년 데이터를 문장 단위로 분리
sentences_2015 = split_into_sentences(text_data["2015년 데이터"])
sentences_2022 = split_into_sentences(text_data["2022년 데이터"])

# 각 기준서(정부 지침서)도 문장 단위로 분리 (17개 문서)
category_sentences = [split_into_sentences(category) for category in categories]

# ====================================
# 2. 한국어에 적합한 SentenceTransformer 모델 로드
# ====================================
# 공개된 한국어 모델로 교체 (jhgan/ko-sroberta-multitask)
model = SentenceTransformer("sentence-transformers/xlm-r-large-en-ko-nli-ststb")

# 2015년과 2022년 문장들의 임베딩은 미리 계산 (속도 향상)
embeddings_2015 = model.encode(sentences_2015, convert_to_tensor=True)
embeddings_2022 = model.encode(sentences_2022, convert_to_tensor=True)

# ====================================
# 3. 기준서별(문서 1~17) 유사도 비교 및 시각화
# ====================================
all_summary = []  # 전체 요약 통계 저장

for cat_idx, cat_sent_list in enumerate(category_sentences, start=1):
    print(f"\n===== 기준서 문서 {cat_idx} =====")

    # 기준서 문장 임베딩 계산
    cat_embeddings = model.encode(cat_sent_list, convert_to_tensor=True)

    # 딕셔너리로 연도별 유사도 저장
    sim_scores_dict = {}
    summary_stats = {}
    best_sentence_pair = {}

    # 2015년과 2022년 각각 처리
    for year_label, year_embeddings, year_sentences in zip(
        ["2015년", "2022년"],
        [embeddings_2015, embeddings_2022],
        [sentences_2015, sentences_2022]
    ):
        # 기준서와 연도 문장 간 코사인 유사도 계산
        sim_matrix = util.cos_sim(cat_embeddings, year_embeddings)
        sim_scores = sim_matrix.cpu().numpy().flatten()
        sim_scores_dict[year_label] = sim_scores

        # 요약 통계 계산
        mean_sim = np.mean(sim_scores)
        min_sim = np.min(sim_scores)
        max_sim = np.max(sim_scores)
        rounded_scores = np.round(sim_scores, 2)
        counter = collections.Counter(rounded_scores)
        mode_val, mode_count = counter.most_common(1)[0]

        summary_stats[year_label] = {
            'Mean': mean_sim,
            'Min': min_sim,
            'Max': max_sim,
            'Mode': mode_val,
            'Mode Count': mode_count
        }

        # 가장 유사한 문장 쌍 찾기
        max_idx = np.argmax(sim_scores)
        num_year = sim_matrix.shape[1]
        cat_sentence_index = max_idx // num_year
        year_sentence_index = max_idx % num_year
        best_sentence_pair[year_label] = {
            'Similarity': sim_scores[max_idx],
            'Category Sentence': cat_sent_list[cat_sentence_index],
            'Year Sentence': year_sentences[year_sentence_index]
        }

    # ---------------------------
    # 3-1. 요약 통계 출력 (DataFrame)
    # ---------------------------
    df_stats = pd.DataFrame(summary_stats).T
    df_stats.index.name = 'Year'
    print("\n[유사도 요약 통계]")
    print(df_stats)

    # ---------------------------
    # 3-2. 두 연도의 유사도 분포를 하나의 DataFrame으로 결합하여 시각화
    # ---------------------------
    df_box = pd.DataFrame({
        'Similarity': np.concatenate([sim_scores_dict['2015년'], sim_scores_dict['2022년']]),
        'Year': ['2015년'] * len(sim_scores_dict['2015년']) + ['2022년'] * len(sim_scores_dict['2022년'])
    })

    # (a) 박스플롯 비교
    plt.figure(figsize=(8, 4))
    sns.boxplot(x='Year', y='Similarity', data=df_box)
    plt.title(f"기준서 {cat_idx} - 연도별 유사도 비교 (Boxplot)")
    plt.ylim(0, 1)
    plt.show()

    # (b) 히스토그램 비교
    plt.figure(figsize=(8, 4))
    bins = np.linspace(0, 1, 21)  # 20 구간
    sns.histplot(data=df_box, x='Similarity', hue='Year', bins=bins, multiple='dodge', edgecolor='black')
    plt.title(f"기준서 {cat_idx} - 연도별 유사도 분포 (Histogram)")
    plt.xlabel("코사인 유사도")
    plt.ylabel("문장 개수")
    plt.show()

    # ---------------------------
    # 3-3. 각 연도별 가장 유사한 문장 쌍 출력
    # ---------------------------
    for year_label in ["2015년", "2022년"]:
        best = best_sentence_pair[year_label]
        print(f"\n[{year_label} - 가장 유사한 문장 쌍 (유사도 {best['Similarity']:.3f})]")
        print("  기준서 문장 :", best['Category Sentence'])
        print("  해당 연도 문장 :", best['Year Sentence'])

    # 요약 통계를 저장 (Category 정보 포함)
    df_stats['Category'] = f"기준서 {cat_idx}"
    all_summary.append(df_stats)

# ====================================
# 4. 전체 기준서 요약 통계 (모든 기준서 비교)
# ====================================
combined_summary = pd.concat(all_summary)
print("\n===== 전체 기준서별 유사도 요약 통계 =====")
print(combined_summary.reset_index())
# Out:
# ===== 기준서 문서 1 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.244203 -0.192480  0.707293  0.23       182.0
# 2022년  0.262101 -0.253607  0.751588  0.29       172.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.707)]
#   기준서 문장 : 개도국 특히 최빈개도국에게 모든 측면에서 빈곤을 종식하기 위한 프로그램과 정책을 이행할 수 있는 적절하고 예측 가능한 수단을 제공하기 위하여 개발 협력 증진 등을 통한 다양한 원천으로부터의 자원의 상당한 동원을 보장한다.
#   해당 연도 문장 : 따라서 생활 자원을 적절히 배분하여 사용함 으로써 자신과 가족의 욕구를 최대한 충족시키고 생활의 질을 향상시킬 수 있도 록 한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.752)]
#   기준서 문장 : 년까지 빈곤층과 취약계층의 회복력을 구축하고 극한 기후에 관련된 사건이나 기타 경제 사회 환경적 충격 및 재난에 대한 노출과 취약성을 감소한다.
#   해당 연도 문장 : 그림 그러므로 자원의 낭비를 최소화하고 환경에 미치는 부정적인 영향과 폐기되는 자원을 줄이려고 노력해야 한다.
#
# ===== 기준서 문서 2 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.219094 -0.212500  0.717188  0.20       213.0
# 2022년  0.302441 -0.216387  0.840178  0.39       171.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.717)]
#   기준서 문장 : 년까지 기아를 종식시키고 영유아를 포함한 모든 사람 특히 빈곤층과 취약계층이 연중 안전하고 영양가 있는 충분한 식량에 대한 접근을 보장한다.
#   해당 연도 문장 : 예를 들어 시간이 부족한 사람이라면 돈이라는 물적 자원 을 활용하여 음식을 사 먹어 시간을 절약할 수 있다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.840)]
#   기준서 문장 : 식료품 시장 및 파생상품 시장의 적절한 기능을 보장할 수 있는 방안을 채택하고 과도한 식량가격의 변동성을 제한할 수 있도록 식량 저장과 같은 시장 정보에의 적시 접근을 원활하게하기 위한 조치를 채택한다.
#   해당 연도 문장 : 식품의 알맞은 보관 방법을 통해 음식물 쓰레기 발생을 줄인다.
#
# ===== 기준서 문서 3 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.213055 -0.182055  0.784752  0.18       315.0
# 2022년  0.242507 -0.188068  0.740476  0.22       293.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.785)]
#   기준서 문장 : 모든 연령층을 위한 건강한 삶 보장과 웰빙 증진 .
#   해당 연도 문장 : .생활자원의 특성 위와 같이 우리의 생명과 건강을 유지하고 욕구를 충족하며 목표를 이루기 위해 사용하는 모든 자원을 생활 자원이라고 한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.740)]
#   기준서 문장 : 년까지 유해 화학물질 대기 수질 토지 공해 및 오염으로 인한 사망과 질병 건수를 상당히 감소한다.
#   해당 연도 문장 : 쓰레기를 줄여 낭비되는 자원을 줄이고 오염 물질을 최소화하는 것을 의미한다.
#
# ===== 기준서 문서 4 =====
#
# [유사도 요약 통계]
#            Mean      Min       Max  Mode  Mode Count
# Year
# 2015년  0.302063 -0.21675  0.750615  0.33       245.0
# 2022년  0.254064 -0.21993  0.778726  0.26       246.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.751)]
#   기준서 문장 : 년까지 취업 양질의 일자리 창업 활동에 필요한 전문 직업 기술 등 적합한 기술을 지닌 청소년과 성인의 수를 실질적으로 늘린다.
#   해당 연도 문장 : 청소년의 자원 관리 청소년의 학업 관리 관리 청소년기는 일상생활을 위한 기본적 지식과 향후 진학과 진로를 결정하는 데 필요한 전문 적 지식을 함양하는 매우 중요한 시기이다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.779)]
#   기준서 문장 : 년까지 취업 양질의 일자리 창업 활동에 필요한 전문 직업 기술 등 적합한 기술을 지닌 청소년과 성인의 수를 실질적으로 늘린다.
#   해당 연도 문장 : 인적 자원 계발하기 꾸준한 노력으로 지식 기술 창의력 등의 인적 자원을 늘린다.
#
# ===== 기준서 문서 5 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.198472 -0.167995  0.805272  0.08       220.0
# 2022년  0.214555 -0.155634  0.726975  0.17       232.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.805)]
#   기준서 문장 : 공공서비스 사회기반시설 및 사회적 보호정책을 제공하고 국가별로 적절하게 가구와 가족 내에서의 책임 분담을 증진함으로써 무상 돌봄과 가사노동을 인정하고 가치 있게 인식한다.
#   해당 연도 문장 : 생활 자원의 특성 생활 자원이란 나와 가족의 욕구를 충족시키고 목표를 달성하는 데 활용할 수 있는 수단과 방법이다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.727)]
#   기준서 문장 : 공공서비스 사회기반시설 및 사회적 보호정책을 제공하고 국가별로 적절하게 가구와 가족 내에서의 책임 분담을 증진함으로써 무상 돌봄과 가사노동을 인정하고 가치 있게 인식한다.
#   해당 연도 문장 : 그중 일상생활에서 나와 가족의 욕구를 충족하고 목표를 달성하기 위해 활용 할 수 있는 모든 수단이나 방법을 생활 자원이라고 한다.
#
# ===== 기준서 문서 6 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.248304 -0.199745  0.646804  0.22       240.0
# 2022년  0.317685 -0.154623  0.834377  0.35       182.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.647)]
#   기준서 문장 : 년까지 집수 담수화 물 효율성 폐수처리 재활용 및 재사용 기술을 포함하는 물과 위생 관련 활동과 프로그램에 있어 개도국 역량 강화 지원과 국제적 협력을 확대한다.
#   해당 연도 문장 : 생 생 활 여 리 물 가 모 적 정 기 선 달 물 인 력 장 시 물 목 차 표 적 물 간 할 일 목 록 노 동 리 평 가 관 생 여 가 치 장 활 산 정 적 자 원 선 지 간 원 실 순 정 복 지 행 위 가 청 소 적 자 원 디 자 년 자 원 관 리 와 자 나와 가족의 욕구를 충족시키고 목표를 달성하는 데 활용할 수 있는 수단과 방법 립 개인이 가진 특성이나 능력에 관련된 자원으로 노력에 따라 높은 수준으로 발전할 수 있는 자원 양과 질을 쉽게 측정할 수 있는 생활 자원 생활하는 데 필요한 에너지를 생산하고 건강한 생명을 유지하는 데 필요한 시간을 생활시간이라고 한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.834)]
#   기준서 문장 : 년까지 오염 저감 유해물질의 투기 근절과 배출 최소화 미처리 폐수 비율 반감 전 세계에서 재활용과 안전한 재사용의 대폭 증진을 통해 수질을 개선한다.
#   해당 연도 문장 : 환경을 위한 노력 친환경 해체 기술을 적용하여 환경 오염 을 최소화한다.
#
# ===== 기준서 문서 7 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.296929 -0.180717  0.674527  0.33       134.0
# 2022년  0.285314 -0.175627  0.747819  0.29       132.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.675)]
#   기준서 문장 : 년까지 개도국 특히 최빈개도국 군소도서개도국 및 내륙개도국에서 각국의 지원 프로그램에 따라 모두를 위한 현대적이고 지속가능한 에너지 서비스를 공급하기 위한 기반시설을 확대하고 기술을 개선한다.
#   해당 연도 문장 : 인적 자원을 최대한 것 지식 기술 창의력 판단력 등의 인적 자원을 꾸준히 개발하여 활용한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.748)]
#   기준서 문장 : 년까지 개도국 특히 최빈개도국 군소도서개도국 및 내륙개도국에서 각국의 지원 프로그램에 따라 모두를 위한 현대적이고 지속가능한 에너지 서비스를 공급하기 위한 기반시설을 확대하고 기술을 개선한다.
#   해당 연도 문장 : 인적 자원 계발하기 꾸준한 노력으로 지식 기술 창의력 등의 인적 자원을 늘린다.
#
# ===== 기준서 문서 8 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.273855 -0.237955  0.686077  0.34       272.0
# 2022년  0.266846 -0.222556  0.808484  0.22       258.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.686)]
#   기준서 문장 : 년까지 청년 고용을 위한 글로벌 전략을 개발하고 운영하며 국제노동 기구 세계고용협약 을 이행한다.
#   해당 연도 문장 : 청소년의 자원 관리 청소년의 학업 관리 관리 청소년기는 일상생활을 위한 기본적 지식과 향후 진학과 진로를 결정하는 데 필요한 전문 적 지식을 함양하는 매우 중요한 시기이다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.808)]
#   기준서 문장 : 지속가능한 소비와 생산에 관한 개년 계획에 따라 선진국들이 주도하여 소비와 생산에 있어서의 전 세계적인 자원 효율성을 년까지 점진적으로 개선하고 경제성장을 환경 악화로부터 분리시키도록 노력한다.
#   해당 연도 문장 : 기대하는 목표 세우기 환경 오염과 기후 위기를 극복할 수 있도록 의식주 생활 자원을 선택할 때 기대하는 목표를 세워 보자.
#
# ===== 기준서 문서 9 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.281822 -0.199415  0.735269  0.26       194.0
# 2022년  0.302992 -0.209776  0.813820  0.30       175.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.735)]
#   기준서 문장 : 모두를 위한 적정가격의 공평한 접근에 중점을 두고 경제발전과 인류의 웰빙을 지원하기 위해 지역별 및 초국경 사회기반시설을 포함하여 양질의 신뢰할 수 있고 지속가능하며 복원력 있는 사회기반시설을 구축한다.
#   해당 연도 문장 : 따라서 생활 자원을 적절히 배분하여 사용함 으로써 자신과 가족의 욕구를 최대한 충족시키고 생활의 질을 향상시킬 수 있도 록 한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.814)]
#   기준서 문장 : 모두를 위한 적정가격의 공평한 접근에 중점을 두고 경제발전과 인류의 웰빙을 지원하기 위해 지역별 및 초국경 사회기반시설을 포함하여 양질의 신뢰할 수 있고 지속가능하며 복원력 있는 사회기반시설을 구축한다.
#   해당 연도 문장 : 그 러므로 의식주 자원을 관리할 때 인간의 욕구 충족 및 목표 달성이라는 가치와 환 경 보전이라는 가치가 서로 적절히 조화를 이룰 수 있도록 해야 한다.
#
# ===== 기준서 문서 10 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.256601 -0.211927  0.706074  0.24       238.0
# 2022년  0.256573 -0.154890  0.719371  0.23       254.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.706)]
#   기준서 문장 : 계획되고 잘 관리된 이주정책 이행 등을 통하여 질서 있고 안전하며 정기적이고 책임감 있는 이주와 사람의 이동을 촉진한다.
#   해당 연도 문장 : 따라서 합리적인 계획과 실천을 통해 자신의 생활을 효율적으로 관리하고 미래의 인생을 설계 하고 준비할 수 있도록 한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.719)]
#   기준서 문장 : 계획되고 잘 관리된 이주정책 이행 등을 통하여 질서 있고 안전하며 정기적이고 책임감 있는 이주와 사람의 이동을 촉진한다.
#   해당 연도 문장 : 생활 자원의 순환 과정을 이해하고 생활 자원을 효율적으로 관리할 수 있다.
#
# ===== 기준서 문서 11 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.268897 -0.172983  0.739594  0.29       250.0
# 2022년  0.307557 -0.148321  0.855683  0.26       220.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.740)]
#   기준서 문장 : 년까지 모두를 위한 적절하고 안전한 적정가격의 주택 및 기초서비스에 대한 접근을 보장하고 빈민가 환경을 개선한다.
#   해당 연도 문장 : 따라서 생활 자원을 적절히 배분하여 사용함 으로써 자신과 가족의 욕구를 최대한 충족시키고 생활의 질을 향상시킬 수 있도 록 한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.856)]
#   기준서 문장 : 년까지 대기질 도시생활 폐기물 및 기타 폐기물 관리에 특별한 주의를 기울임으로써 도시의 인당 부정적 환경영향을 줄인다.
#   해당 연도 문장 : 쓰레기 배출량을 에 가깝게 줄여 환경을 보호하는 실천 운동이지.
#
# ===== 기준서 문서 12 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.281943 -0.174630  0.735414  0.29       238.0
# 2022년  0.344523 -0.186535  0.911647  0.34       215.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.735)]
#   기준서 문장 : 년까지 유통 및 소비자 수준에서의 전 세계 인구 인당 음식물쓰레기 발생량을 절반으로 줄이고 출하 후 손실을 포함한 식품의 생산 및 공급망에서 발생하는 식품 손실을 감소한다.
#   해당 연도 문장 : 예를 들어 시간이 부족한 사람이라면 돈이라는 물적 자원 을 활용하여 음식을 사 먹어 시간을 절약할 수 있다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.912)]
#   기준서 문장 : 년까지 예방 감축 재활용 및 재사용을 통해 폐기물 발생을 상당히 줄인다.
#   해당 연도 문장 : 쓰레기를 줄여 낭비되는 자원을 줄이고 오염 물질을 최소화하는 것을 의미한다.
#
# ===== 기준서 문서 13 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.264773 -0.145385  0.667254  0.27       145.0
# 2022년  0.325397 -0.158451  0.850277  0.38       128.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.667)]
#   기준서 문장 : 기후변화의 완화 적응 영향 감소 조기 경보 등에 관한 교육 인식제고 인적 제도적 역량을 강화한다.
#   해당 연도 문장 : .청소년의 자원관리 재 미 있 는 가 정 활 동 평소 자신의 하루 생활시간을 적어 보고 문제점을 분석한 후 삶의 질을 향상하기 위한 방법을 알아보자.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.850)]
#   기준서 문장 : 기후변화 대응조치를 국가 정책 전략 및 계획에 통합한다.
#   해당 연도 문장 : 기후 위기 문제를 해결하기 위해 국가나 지역 단체 기업 등에서 하고 있는 노력을 조사해 보자.
#
# ===== 기준서 문서 14 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.237740 -0.178610  0.716429  0.21       269.0
# 2022년  0.299942 -0.198513  0.785288  0.28       225.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.716)]
#   기준서 문장 : 년까지 심각한 악영향을 피하고자 회복력을 강화하는 방법을 포함하여 해양과 연안의 생태계를 지속가능하게 관리하고 보호하며 건강하고 생산적인 해양을 조성하기 위해 복원 조치를 시행한다.
#   해당 연도 문장 : 물품은 깨끗이 사용하고 고장이 나면 바로 수리하는 등 자원을 잘 관리하면 더 오래 사용할 수 있다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.785)]
#   기준서 문장 : 년까지 해양 쓰레기와 영양염류 오염을 포함하여 특히 육상활동에서 발생하는 모든 종류의 해양 오염을 예방하고 상당한 수준으로 줄인다.
#   해당 연도 문장 : 환경을 위한 노력 친환경 해체 기술을 적용하여 환경 오염 을 최소화한다.
#
# ===== 기준서 문서 15 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.236826 -0.189141  0.701228  0.23       321.0
# 2022년  0.320815 -0.271212  0.799343  0.42       242.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.701)]
#   기준서 문장 : 년까지 생태계와 생물다양성의 가치를 국가 지역 계획 개발 프로세스 및 빈곤감소 전략과 회계 에 통합한다.
#   해당 연도 문장 : 그림 자원의 효율적인 관리 방법 내가 가지고 있는 생활 자원을 분류하고 관리 계획을 세워 보자.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.799)]
#   기준서 문장 : 년까지 생태계와 생물다양성의 가치를 국가 지역 계획 개발 프로세스 및 빈곤감소 전략과 회계 에 통합한다.
#   해당 연도 문장 : 생활 자원의 순환과 의식주 자원 관리 의식주 생활 자원의 선택 과정과 결과의 성찰 의식주 생활 자원의 선택이 환경에 미치는 영향은 그림 과 같은 실천적 추 론 과정에 따라 성찰해 볼 수 있다.
#
# ===== 기준서 문서 16 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.234151 -0.200659  0.724273  0.23       278.0
# 2022년  0.236895 -0.174198  0.730869  0.19       305.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.724)]
#   기준서 문장 : 효과적이고 책임성 있으며 투명한 제도를 모든 단계의 기관에 구축한다.
#   해당 연도 문장 : 목표 세우기 명확하고 구체적으로 목표를 정한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.731)]
#   기준서 문장 : 지속가능발전을 위한 평화롭고 포용적인 사회 증진 모두에게 정의 보장과 모든 수준에서 효과적이고 책임성 있으며 포용적인 제도 구축 .
#   해당 연도 문장 : 이러한 일상생활 속 작은 선택들이 쌓여 환경을 보호할 수 있으며 기후 위기에 취약한 사회적 약자를 보호함으로써 함께 살아가는 사회적 가치를 실현할 수 있다.
#
# ===== 기준서 문서 17 =====
#
# [유사도 요약 통계]
#            Mean       Min       Max  Mode  Mode Count
# Year
# 2015년  0.267706 -0.206497  0.778748  0.28       479.0
# 2022년  0.273205 -0.201710  0.748239  0.29       473.0
# [2015년 - 가장 유사한 문장 쌍 (유사도 0.779)]
#   기준서 문장 : 파트너십의 경험과 재원조달 전략을 바탕으로 효과적인 공공 민관 시민사회의 파트너십을 장려하고 도모한다.
#   해당 연도 문장 : 다른 사람들과의 협동을 통해 대인적 자원을 계발한다.
#
# [2022년 - 가장 유사한 문장 쌍 (유사도 0.748)]
#   기준서 문장 : 제공을 목표로 설정하는 것을 고려하도록 장려한다.
#   해당 연도 문장 : 가치 태도 의식주 생활 자원의 순환을 위해 우리가 할 수 있는 일을 이야기해 보자.
#
# ===== 전체 기준서별 유사도 요약 통계 =====
#      Year      Mean       Min       Max  Mode  Mode Count Category
# 0   2015년  0.244203 -0.192480  0.707293  0.23       182.0    기준서 1
# 1   2022년  0.262101 -0.253607  0.751588  0.29       172.0    기준서 1
# 2   2015년  0.219094 -0.212500  0.717188  0.20       213.0    기준서 2
# 3   2022년  0.302441 -0.216387  0.840178  0.39       171.0    기준서 2
# 4   2015년  0.213055 -0.182055  0.784752  0.18       315.0    기준서 3
# 5   2022년  0.242507 -0.188068  0.740476  0.22       293.0    기준서 3
# 6   2015년  0.302063 -0.216750  0.750615  0.33       245.0    기준서 4
# 7   2022년  0.254064 -0.219930  0.778726  0.26       246.0    기준서 4
# 8   2015년  0.198472 -0.167995  0.805272  0.08       220.0    기준서 5
# 9   2022년  0.214555 -0.155634  0.726975  0.17       232.0    기준서 5
# 10  2015년  0.248304 -0.199745  0.646804  0.22       240.0    기준서 6
# 11  2022년  0.317685 -0.154623  0.834377  0.35       182.0    기준서 6
# 12  2015년  0.296929 -0.180717  0.674527  0.33       134.0    기준서 7
# 13  2022년  0.285314 -0.175627  0.747819  0.29       132.0    기준서 7
# 14  2015년  0.273855 -0.237955  0.686077  0.34       272.0    기준서 8
# 15  2022년  0.266846 -0.222556  0.808484  0.22       258.0    기준서 8
# 16  2015년  0.281822 -0.199415  0.735269  0.26       194.0    기준서 9
# 17  2022년  0.302992 -0.209776  0.813820  0.30       175.0    기준서 9
# 18  2015년  0.256601 -0.211927  0.706074  0.24       238.0   기준서 10
# 19  2022년  0.256573 -0.154890  0.719371  0.23       254.0   기준서 10
# 20  2015년  0.268897 -0.172983  0.739594  0.29       250.0   기준서 11
# 21  2022년  0.307557 -0.148321  0.855683  0.26       220.0   기준서 11
# 22  2015년  0.281943 -0.174630  0.735414  0.29       238.0   기준서 12
# 23  2022년  0.344523 -0.186535  0.911647  0.34       215.0   기준서 12
# 24  2015년  0.264773 -0.145385  0.667254  0.27       145.0   기준서 13
# 25  2022년  0.325397 -0.158451  0.850277  0.38       128.0   기준서 13
# 26  2015년  0.237740 -0.178610  0.716429  0.21       269.0   기준서 14
# 27  2022년  0.299942 -0.198513  0.785288  0.28       225.0   기준서 14
# 28  2015년  0.236826 -0.189141  0.701228  0.23       321.0   기준서 15
# 29  2022년  0.320815 -0.271212  0.799343  0.42       242.0   기준서 15
# 30  2015년  0.234151 -0.200659  0.724273  0.23       278.0   기준서 16
# 31  2022년  0.236895 -0.174198  0.730869  0.19       305.0   기준서 16
# 32  2015년  0.267706 -0.206497  0.778748  0.28       479.0   기준서 17
# 33  2022년  0.273205 -0.201710  0.748239  0.29       473.0   기준서 17
